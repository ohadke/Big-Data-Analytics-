# %%
import pyspark
import os
import re
sc = pyspark.SparkContext.getOrCreate()

# %%
import nltk
from nltk import word_tokenize

# %%
##nltk.download()

# %%
#here we load the data and for every file we get row with key-value set 
#key= the path of the file, value = content of the file

# %%
files_rdd = sc.wholeTextFiles("data/*/*.txt")
files_rdd.toDF(["path","text"]).toPandas()
# Out:
#                                                   path  \
# 0    file:/home/edenpa/BigData/project1/data/busine...
# 1    file:/home/edenpa/BigData/project1/data/busine...
# 2    file:/home/edenpa/BigData/project1/data/busine...
# 3    file:/home/edenpa/BigData/project1/data/busine...
# 4    file:/home/edenpa/BigData/project1/data/busine...
# 5    file:/home/edenpa/BigData/project1/data/busine...
# 6    file:/home/edenpa/BigData/project1/data/busine...
# 7    file:/home/edenpa/BigData/project1/data/busine...
# 8    file:/home/edenpa/BigData/project1/data/busine...
# 9    file:/home/edenpa/BigData/project1/data/busine...
# 10   file:/home/edenpa/BigData/project1/data/busine...
# 11   file:/home/edenpa/BigData/project1/data/busine...
# 12   file:/home/edenpa/BigData/project1/data/busine...
# 13   file:/home/edenpa/BigData/project1/data/busine...
# 14   file:/home/edenpa/BigData/project1/data/busine...
# 15   file:/home/edenpa/BigData/project1/data/busine...
# 16   file:/home/edenpa/BigData/project1/data/busine...
# 17   file:/home/edenpa/BigData/project1/data/busine...
# 18   file:/home/edenpa/BigData/project1/data/busine...
# 19   file:/home/edenpa/BigData/project1/data/busine...
# 20   file:/home/edenpa/BigData/project1/data/busine...
# 21   file:/home/edenpa/BigData/project1/data/busine...
# 22   file:/home/edenpa/BigData/project1/data/busine...
# 23   file:/home/edenpa/BigData/project1/data/busine...
# 24   file:/home/edenpa/BigData/project1/data/busine...
# 25   file:/home/edenpa/BigData/project1/data/busine...
# 26   file:/home/edenpa/BigData/project1/data/busine...
# 27   file:/home/edenpa/BigData/project1/data/busine...
# 28   file:/home/edenpa/BigData/project1/data/busine...
# 29   file:/home/edenpa/BigData/project1/data/busine...
# ..                                                 ...
# 481  file:/home/edenpa/BigData/project1/data/entert...
# 482  file:/home/edenpa/BigData/project1/data/entert...
# 483  file:/home/edenpa/BigData/project1/data/entert...
# 484  file:/home/edenpa/BigData/project1/data/entert...
# 485  file:/home/edenpa/BigData/project1/data/entert...
# 486  file:/home/edenpa/BigData/project1/data/entert...
# 487  file:/home/edenpa/BigData/project1/data/entert...
# 488  file:/home/edenpa/BigData/project1/data/entert...
# 489  file:/home/edenpa/BigData/project1/data/entert...
# 490  file:/home/edenpa/BigData/project1/data/entert...
# 491  file:/home/edenpa/BigData/project1/data/entert...
# 492  file:/home/edenpa/BigData/project1/data/entert...
# 493  file:/home/edenpa/BigData/project1/data/entert...
# 494  file:/home/edenpa/BigData/project1/data/entert...
# 495  file:/home/edenpa/BigData/project1/data/entert...
# 496  file:/home/edenpa/BigData/project1/data/entert...
# 497  file:/home/edenpa/BigData/project1/data/entert...
# 498  file:/home/edenpa/BigData/project1/data/entert...
# 499  file:/home/edenpa/BigData/project1/data/entert...
# 500  file:/home/edenpa/BigData/project1/data/entert...
# 501  file:/home/edenpa/BigData/project1/data/entert...
# 502  file:/home/edenpa/BigData/project1/data/entert...
# 503  file:/home/edenpa/BigData/project1/data/entert...
# 504  file:/home/edenpa/BigData/project1/data/entert...
# 505  file:/home/edenpa/BigData/project1/data/entert...
# 506  file:/home/edenpa/BigData/project1/data/entert...
# 507  file:/home/edenpa/BigData/project1/data/entert...
# 508  file:/home/edenpa/BigData/project1/data/entert...
# 509  file:/home/edenpa/BigData/project1/data/entert...
# 510  file:/home/edenpa/BigData/project1/data/entert...
#
#                                                   text
# 0    Yukos unit buyer faces loan claim\n\nThe owner...
# 1    Soaring oil 'hits world economy'\n\nThe soarin...
# 2    Weak dollar hits Reuters\n\nRevenues at media ...
# 3    Palestinian economy in decline\n\nDespite a sh...
# 4    BMW drives record sales in Asia\n\nBMW has for...
# 5    Metlife buys up Citigroup insurer\n\nUS bankin...
# 6    Parmalat boasts doubled profits\n\nParmalat, t...
# 7    India widens access to telecoms\n\nIndia has r...
# 8    Japanese banking battle at an end\n\nJapan's S...
# 9    Ask Jeeves tips online ad revival\n\nAsk Jeeve...
# 10   EU aiming to fuel development aid\n\nEuropean ...
# 11   Japanese mogul arrested for fraud\n\nOne of Ja...
# 12   EU ministers to mull jet fuel tax\n\nEuropean ...
# 13   Burren awarded Egyptian contracts\n\nBritish e...
# 14   Telegraph newspapers axe 90 jobs\n\nThe Daily ...
# 15   Iranian MPs threaten mobile deal\n\nTurkey's b...
# 16   Dollar gains on Greenspan speech\n\nThe dollar...
# 17   Lufthansa may sue over Bush visit\n\nGerman ai...
# 18   Jobs growth still slow in the US\n\nThe US cre...
# 19   Yukos accused of lying to court\n\nRussian oil...
# 20   Peugeot deal boosts Mitsubishi\n\nStruggling J...
# 21   Chinese wine tempts Italy's Illva\n\nItaly's I...
# 22   Fed chief warning on US deficit\n\nFederal Res...
# 23   US economy shows solid GDP growth\n\nThe US ec...
# 24   US gives foreign firms extra time\n\nForeign f...
# 25   US trade gap hits record in 2004\n\nThe gap be...
# 26   Hyundai to build new India plant\n\nSouth Kore...
# 27   Electrolux to export Europe jobs\n\nElectrolux...
# 28   Worldcom ex-boss launches defence\n\nLawyers d...
# 29   Circuit City gets takeover offer\n\nCircuit Ci...
# ..                                                 ...
# 481  Gallery unveils interactive tree\n\nA Christma...
# 482  Ray DVD beats box office takings\n\nOscar-nomi...
# 483  Bookmakers back Aviator for Oscar\n\nThe Aviat...
# 484  Foxx and Swank win US awards\n\nJamie Foxx and...
# 485  Obituary: Dame Alicia Markova\n\nDame Alicia M...
# 486  Fears raised over ballet future\n\nFewer child...
# 487  Stars gear up for Bafta ceremony\n\nFilm stars...
# 488  Box office blow for Alexander\n\nDirector Oliv...
# 489  Dirty Den's demise seen by 14m\n\nMore than 14...
# 490  Aviator wins top Globes accolades\n\nThe Aviat...
# 491  New Harry Potter tops book chart\n\nHarry Pott...
# 492  Surprise win for anti-Bush film\n\nMichael Moo...
# 493  Spirit awards hail Sideways\n\nThe comedy Side...
# 494  Hundreds vie for best film Oscar\n\nA total of...
# 495  De Niro film leads US box office\n\nFilm star ...
# 496  Versace art portfolio up for sale\n\nThe art c...
# 497  Famed music director Viotti dies\n\nConductor ...
# 498  Tautou 'to star in Da Vinci film'\n\nFrench ac...
# 499  Stars pay tribute to actor Davis\n\nHollywood ...
# 500  Ocean's Twelve raids box office\n\nOcean's Twe...
# 501  Arthur Hailey: King of the bestsellers\n\nNove...
# 502  Mutant book wins Guardian prize\n\nA book abou...
# 503  Berlin applauds Hotel Rwanda\n\nPolitical thri...
# 504  Jugnot 'tops French actor league'\n\nActor Ger...
# 505  DVD review: I, Robot\n\nOnly one man recognise...
# 506  Wine comedy up for six film gongs\n\nSideways,...
# 507  Willis sues over movie 'injury'\n\nActor Bruce...
# 508  Foxx and Swank take actors awards\n\nJamie Fox...
# 509  Uganda bans Vagina Monologues\n\nUganda's auth...
# 510  Aviator 'creator' in Oscars snub\n\nThe man wh...
#
# [511 rows x 2 columns]

# %%
#here we organize the data, every line as such
#[category, article name, article text]

# %%
files_rdd = files_rdd.map(lambda (k,v): (k.split('/')[-2],v.split('\n', 1)[0] ,v))
files_rdd.toDF(["category", "article_name", "article_text"]).toPandas()
# Out:
#           category                            article_name  \
# 0         business       Yukos unit buyer faces loan claim
# 1         business        Soaring oil 'hits world economy'
# 2         business                Weak dollar hits Reuters
# 3         business          Palestinian economy in decline
# 4         business         BMW drives record sales in Asia
# 5         business       Metlife buys up Citigroup insurer
# 6         business         Parmalat boasts doubled profits
# 7         business         India widens access to telecoms
# 8         business       Japanese banking battle at an end
# 9         business       Ask Jeeves tips online ad revival
# 10        business       EU aiming to fuel development aid
# 11        business       Japanese mogul arrested for fraud
# 12        business       EU ministers to mull jet fuel tax
# 13        business       Burren awarded Egyptian contracts
# 14        business        Telegraph newspapers axe 90 jobs
# 15        business        Iranian MPs threaten mobile deal
# 16        business        Dollar gains on Greenspan speech
# 17        business       Lufthansa may sue over Bush visit
# 18        business        Jobs growth still slow in the US
# 19        business         Yukos accused of lying to court
# 20        business          Peugeot deal boosts Mitsubishi
# 21        business       Chinese wine tempts Italy's Illva
# 22        business         Fed chief warning on US deficit
# 23        business       US economy shows solid GDP growth
# 24        business       US gives foreign firms extra time
# 25        business        US trade gap hits record in 2004
# 26        business        Hyundai to build new India plant
# 27        business        Electrolux to export Europe jobs
# 28        business       Worldcom ex-boss launches defence
# 29        business        Circuit City gets takeover offer
# ..             ...                                     ...
# 481  entertainment        Gallery unveils interactive tree
# 482  entertainment        Ray DVD beats box office takings
# 483  entertainment       Bookmakers back Aviator for Oscar
# 484  entertainment            Foxx and Swank win US awards
# 485  entertainment           Obituary: Dame Alicia Markova
# 486  entertainment         Fears raised over ballet future
# 487  entertainment        Stars gear up for Bafta ceremony
# 488  entertainment           Box office blow for Alexander
# 489  entertainment          Dirty Den's demise seen by 14m
# 490  entertainment       Aviator wins top Globes accolades
# 491  entertainment        New Harry Potter tops book chart
# 492  entertainment         Surprise win for anti-Bush film
# 493  entertainment             Spirit awards hail Sideways
# 494  entertainment        Hundreds vie for best film Oscar
# 495  entertainment        De Niro film leads US box office
# 496  entertainment       Versace art portfolio up for sale
# 497  entertainment        Famed music director Viotti dies
# 498  entertainment       Tautou 'to star in Da Vinci film'
# 499  entertainment        Stars pay tribute to actor Davis
# 500  entertainment         Ocean's Twelve raids box office
# 501  entertainment  Arthur Hailey: King of the bestsellers
# 502  entertainment         Mutant book wins Guardian prize
# 503  entertainment            Berlin applauds Hotel Rwanda
# 504  entertainment       Jugnot 'tops French actor league'
# 505  entertainment                    DVD review: I, Robot
# 506  entertainment       Wine comedy up for six film gongs
# 507  entertainment         Willis sues over movie 'injury'
# 508  entertainment       Foxx and Swank take actors awards
# 509  entertainment           Uganda bans Vagina Monologues
# 510  entertainment        Aviator 'creator' in Oscars snub
#
#                                           article_text
# 0    Yukos unit buyer faces loan claim\n\nThe owner...
# 1    Soaring oil 'hits world economy'\n\nThe soarin...
# 2    Weak dollar hits Reuters\n\nRevenues at media ...
# 3    Palestinian economy in decline\n\nDespite a sh...
# 4    BMW drives record sales in Asia\n\nBMW has for...
# 5    Metlife buys up Citigroup insurer\n\nUS bankin...
# 6    Parmalat boasts doubled profits\n\nParmalat, t...
# 7    India widens access to telecoms\n\nIndia has r...
# 8    Japanese banking battle at an end\n\nJapan's S...
# 9    Ask Jeeves tips online ad revival\n\nAsk Jeeve...
# 10   EU aiming to fuel development aid\n\nEuropean ...
# 11   Japanese mogul arrested for fraud\n\nOne of Ja...
# 12   EU ministers to mull jet fuel tax\n\nEuropean ...
# 13   Burren awarded Egyptian contracts\n\nBritish e...
# 14   Telegraph newspapers axe 90 jobs\n\nThe Daily ...
# 15   Iranian MPs threaten mobile deal\n\nTurkey's b...
# 16   Dollar gains on Greenspan speech\n\nThe dollar...
# 17   Lufthansa may sue over Bush visit\n\nGerman ai...
# 18   Jobs growth still slow in the US\n\nThe US cre...
# 19   Yukos accused of lying to court\n\nRussian oil...
# 20   Peugeot deal boosts Mitsubishi\n\nStruggling J...
# 21   Chinese wine tempts Italy's Illva\n\nItaly's I...
# 22   Fed chief warning on US deficit\n\nFederal Res...
# 23   US economy shows solid GDP growth\n\nThe US ec...
# 24   US gives foreign firms extra time\n\nForeign f...
# 25   US trade gap hits record in 2004\n\nThe gap be...
# 26   Hyundai to build new India plant\n\nSouth Kore...
# 27   Electrolux to export Europe jobs\n\nElectrolux...
# 28   Worldcom ex-boss launches defence\n\nLawyers d...
# 29   Circuit City gets takeover offer\n\nCircuit Ci...
# ..                                                 ...
# 481  Gallery unveils interactive tree\n\nA Christma...
# 482  Ray DVD beats box office takings\n\nOscar-nomi...
# 483  Bookmakers back Aviator for Oscar\n\nThe Aviat...
# 484  Foxx and Swank win US awards\n\nJamie Foxx and...
# 485  Obituary: Dame Alicia Markova\n\nDame Alicia M...
# 486  Fears raised over ballet future\n\nFewer child...
# 487  Stars gear up for Bafta ceremony\n\nFilm stars...
# 488  Box office blow for Alexander\n\nDirector Oliv...
# 489  Dirty Den's demise seen by 14m\n\nMore than 14...
# 490  Aviator wins top Globes accolades\n\nThe Aviat...
# 491  New Harry Potter tops book chart\n\nHarry Pott...
# 492  Surprise win for anti-Bush film\n\nMichael Moo...
# 493  Spirit awards hail Sideways\n\nThe comedy Side...
# 494  Hundreds vie for best film Oscar\n\nA total of...
# 495  De Niro film leads US box office\n\nFilm star ...
# 496  Versace art portfolio up for sale\n\nThe art c...
# 497  Famed music director Viotti dies\n\nConductor ...
# 498  Tautou 'to star in Da Vinci film'\n\nFrench ac...
# 499  Stars pay tribute to actor Davis\n\nHollywood ...
# 500  Ocean's Twelve raids box office\n\nOcean's Twe...
# 501  Arthur Hailey: King of the bestsellers\n\nNove...
# 502  Mutant book wins Guardian prize\n\nA book abou...
# 503  Berlin applauds Hotel Rwanda\n\nPolitical thri...
# 504  Jugnot 'tops French actor league'\n\nActor Ger...
# 505  DVD review: I, Robot\n\nOnly one man recognise...
# 506  Wine comedy up for six film gongs\n\nSideways,...
# 507  Willis sues over movie 'injury'\n\nActor Bruce...
# 508  Foxx and Swank take actors awards\n\nJamie Fox...
# 509  Uganda bans Vagina Monologues\n\nUganda's auth...
# 510  Aviator 'creator' in Oscars snub\n\nThe man wh...
#
# [511 rows x 3 columns]

# %%
# 2.a & b: divide every article text to tokens and remove stop words

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))
stop_words_broadcast = sc.broadcast(stop_words)

# %%
def tokenizeWithoutStopWords(text):
    filter_tokens = []
    tokens = word_tokenize(re.sub("[^A-Za-z]+"," ",text.lower()))
    for w in tokens:
        if w not in stop_words_broadcast.value and len(w) > 1:
            filter_tokens.append(w)

    return filter_tokens

# %%
#here we separate the content of each file to tokens and remove stop words from the tokens
#every row: [category, article name, tokens]

# %%
TEXT = 2
files_devide_to_tokens_rdd = files_rdd.map(lambda row: [row[0], row[1],tokenizeWithoutStopWords(row[TEXT])])

files_devide_to_tokens_rdd.toDF(["category", "article_name", "tokens"]).toPandas()
# Out:
#           category                            article_name  \
# 0         business       Yukos unit buyer faces loan claim
# 1         business        Soaring oil 'hits world economy'
# 2         business                Weak dollar hits Reuters
# 3         business          Palestinian economy in decline
# 4         business         BMW drives record sales in Asia
# 5         business       Metlife buys up Citigroup insurer
# 6         business         Parmalat boasts doubled profits
# 7         business         India widens access to telecoms
# 8         business       Japanese banking battle at an end
# 9         business       Ask Jeeves tips online ad revival
# 10        business       EU aiming to fuel development aid
# 11        business       Japanese mogul arrested for fraud
# 12        business       EU ministers to mull jet fuel tax
# 13        business       Burren awarded Egyptian contracts
# 14        business        Telegraph newspapers axe 90 jobs
# 15        business        Iranian MPs threaten mobile deal
# 16        business        Dollar gains on Greenspan speech
# 17        business       Lufthansa may sue over Bush visit
# 18        business        Jobs growth still slow in the US
# 19        business         Yukos accused of lying to court
# 20        business          Peugeot deal boosts Mitsubishi
# 21        business       Chinese wine tempts Italy's Illva
# 22        business         Fed chief warning on US deficit
# 23        business       US economy shows solid GDP growth
# 24        business       US gives foreign firms extra time
# 25        business        US trade gap hits record in 2004
# 26        business        Hyundai to build new India plant
# 27        business        Electrolux to export Europe jobs
# 28        business       Worldcom ex-boss launches defence
# 29        business        Circuit City gets takeover offer
# ..             ...                                     ...
# 481  entertainment        Gallery unveils interactive tree
# 482  entertainment        Ray DVD beats box office takings
# 483  entertainment       Bookmakers back Aviator for Oscar
# 484  entertainment            Foxx and Swank win US awards
# 485  entertainment           Obituary: Dame Alicia Markova
# 486  entertainment         Fears raised over ballet future
# 487  entertainment        Stars gear up for Bafta ceremony
# 488  entertainment           Box office blow for Alexander
# 489  entertainment          Dirty Den's demise seen by 14m
# 490  entertainment       Aviator wins top Globes accolades
# 491  entertainment        New Harry Potter tops book chart
# 492  entertainment         Surprise win for anti-Bush film
# 493  entertainment             Spirit awards hail Sideways
# 494  entertainment        Hundreds vie for best film Oscar
# 495  entertainment        De Niro film leads US box office
# 496  entertainment       Versace art portfolio up for sale
# 497  entertainment        Famed music director Viotti dies
# 498  entertainment       Tautou 'to star in Da Vinci film'
# 499  entertainment        Stars pay tribute to actor Davis
# 500  entertainment         Ocean's Twelve raids box office
# 501  entertainment  Arthur Hailey: King of the bestsellers
# 502  entertainment         Mutant book wins Guardian prize
# 503  entertainment            Berlin applauds Hotel Rwanda
# 504  entertainment       Jugnot 'tops French actor league'
# 505  entertainment                    DVD review: I, Robot
# 506  entertainment       Wine comedy up for six film gongs
# 507  entertainment         Willis sues over movie 'injury'
# 508  entertainment       Foxx and Swank take actors awards
# 509  entertainment           Uganda bans Vagina Monologues
# 510  entertainment        Aviator 'creator' in Oscars snub
#
#                                                 tokens
# 0    [yukos, unit, buyer, faces, loan, claim, owner...
# 1    [soaring, oil, hits, world, economy, soaring, ...
# 2    [weak, dollar, hits, reuters, revenues, media,...
# 3    [palestinian, economy, decline, despite, short...
# 4    [bmw, drives, record, sales, asia, bmw, foreca...
# 5    [metlife, buys, citigroup, insurer, us, bankin...
# 6    [parmalat, boasts, doubled, profits, parmalat,...
# 7    [india, widens, access, telecoms, india, raise...
# 8    [japanese, banking, battle, end, japan, sumito...
# 9    [ask, jeeves, tips, online, ad, revival, ask, ...
# 10   [eu, aiming, fuel, development, aid, european,...
# 11   [japanese, mogul, arrested, fraud, one, japan,...
# 12   [eu, ministers, mull, jet, fuel, tax, european...
# 13   [burren, awarded, egyptian, contracts, british...
# 14   [telegraph, newspapers, axe, jobs, daily, sund...
# 15   [iranian, mps, threaten, mobile, deal, turkey,...
# 16   [dollar, gains, greenspan, speech, dollar, hit...
# 17   [lufthansa, may, sue, bush, visit, german, air...
# 18   [jobs, growth, still, slow, us, us, created, f...
# 19   [yukos, accused, lying, court, russian, oil, f...
# 20   [peugeot, deal, boosts, mitsubishi, struggling...
# 21   [chinese, wine, tempts, italy, illva, italy, i...
# 22   [fed, chief, warning, us, deficit, federal, re...
# 23   [us, economy, shows, solid, gdp, growth, us, e...
# 24   [us, gives, foreign, firms, extra, time, forei...
# 25   [us, trade, gap, hits, record, gap, us, export...
# 26   [hyundai, build, new, india, plant, south, kor...
# 27   [electrolux, export, europe, jobs, electrolux,...
# 28   [worldcom, ex, boss, launches, defence, lawyer...
# 29   [circuit, city, gets, takeover, offer, circuit...
# ..                                                 ...
# 481  [gallery, unveils, interactive, tree, christma...
# 482  [ray, dvd, beats, box, office, takings, oscar,...
# 483  [bookmakers, back, aviator, oscar, aviator, ti...
# 484  [foxx, swank, win, us, awards, jamie, foxx, hi...
# 485  [obituary, dame, alicia, markova, dame, alicia...
# 486  [fears, raised, ballet, future, fewer, childre...
# 487  [stars, gear, bafta, ceremony, film, stars, ac...
# 488  [box, office, blow, alexander, director, olive...
# 489  [dirty, den, demise, seen, million, people, sa...
# 490  [aviator, wins, top, globes, accolades, aviato...
# 491  [new, harry, potter, tops, book, chart, harry,...
# 492  [surprise, win, anti, bush, film, michael, moo...
# 493  [spirit, awards, hail, sideways, comedy, sidew...
# 494  [hundreds, vie, best, film, oscar, total, film...
# 495  [de, niro, film, leads, us, box, office, film,...
# 496  [versace, art, portfolio, sale, art, collectio...
# 497  [famed, music, director, viotti, dies, conduct...
# 498  [tautou, star, da, vinci, film, french, actres...
# 499  [stars, pay, tribute, actor, davis, hollywood,...
# 500  [ocean, twelve, raids, box, office, ocean, twe...
# 501  [arthur, hailey, king, bestsellers, novelist, ...
# 502  [mutant, book, wins, guardian, prize, book, ev...
# 503  [berlin, applauds, hotel, rwanda, political, t...
# 504  [jugnot, tops, french, actor, league, actor, g...
# 505  [dvd, review, robot, one, man, recognises, rob...
# 506  [wine, comedy, six, film, gongs, sideways, win...
# 507  [willis, sues, movie, injury, actor, bruce, wi...
# 508  [foxx, swank, take, actors, awards, jamie, fox...
# 509  [uganda, bans, vagina, monologues, uganda, aut...
# 510  [aviator, creator, oscars, snub, man, said, go...
#
# [511 rows x 3 columns]

# %%
#2.d: creating TFtd table

# %%
#this function create dictionary of term frequency
def calculate_TFt(tokens_list):
    counter = {}
    for token in tokens_list:
        counter[token] = counter.get(token, 0) + 1
    return counter

# %%
files_with_tf_rdd = files_devide_to_tokens_rdd.map(lambda row: [row[0],row[1],calculate_TFt(row[2])])
files_with_tf_rdd.toDF(["category", "article_name", "tf"]).toPandas()
# Out:
#           category                            article_name  \
# 0         business       Yukos unit buyer faces loan claim
# 1         business        Soaring oil 'hits world economy'
# 2         business                Weak dollar hits Reuters
# 3         business          Palestinian economy in decline
# 4         business         BMW drives record sales in Asia
# 5         business       Metlife buys up Citigroup insurer
# 6         business         Parmalat boasts doubled profits
# 7         business         India widens access to telecoms
# 8         business       Japanese banking battle at an end
# 9         business       Ask Jeeves tips online ad revival
# 10        business       EU aiming to fuel development aid
# 11        business       Japanese mogul arrested for fraud
# 12        business       EU ministers to mull jet fuel tax
# 13        business       Burren awarded Egyptian contracts
# 14        business        Telegraph newspapers axe 90 jobs
# 15        business        Iranian MPs threaten mobile deal
# 16        business        Dollar gains on Greenspan speech
# 17        business       Lufthansa may sue over Bush visit
# 18        business        Jobs growth still slow in the US
# 19        business         Yukos accused of lying to court
# 20        business          Peugeot deal boosts Mitsubishi
# 21        business       Chinese wine tempts Italy's Illva
# 22        business         Fed chief warning on US deficit
# 23        business       US economy shows solid GDP growth
# 24        business       US gives foreign firms extra time
# 25        business        US trade gap hits record in 2004
# 26        business        Hyundai to build new India plant
# 27        business        Electrolux to export Europe jobs
# 28        business       Worldcom ex-boss launches defence
# 29        business        Circuit City gets takeover offer
# ..             ...                                     ...
# 481  entertainment        Gallery unveils interactive tree
# 482  entertainment        Ray DVD beats box office takings
# 483  entertainment       Bookmakers back Aviator for Oscar
# 484  entertainment            Foxx and Swank win US awards
# 485  entertainment           Obituary: Dame Alicia Markova
# 486  entertainment         Fears raised over ballet future
# 487  entertainment        Stars gear up for Bafta ceremony
# 488  entertainment           Box office blow for Alexander
# 489  entertainment          Dirty Den's demise seen by 14m
# 490  entertainment       Aviator wins top Globes accolades
# 491  entertainment        New Harry Potter tops book chart
# 492  entertainment         Surprise win for anti-Bush film
# 493  entertainment             Spirit awards hail Sideways
# 494  entertainment        Hundreds vie for best film Oscar
# 495  entertainment        De Niro film leads US box office
# 496  entertainment       Versace art portfolio up for sale
# 497  entertainment        Famed music director Viotti dies
# 498  entertainment       Tautou 'to star in Da Vinci film'
# 499  entertainment        Stars pay tribute to actor Davis
# 500  entertainment         Ocean's Twelve raids box office
# 501  entertainment  Arthur Hailey: King of the bestsellers
# 502  entertainment         Mutant book wins Guardian prize
# 503  entertainment            Berlin applauds Hotel Rwanda
# 504  entertainment       Jugnot 'tops French actor league'
# 505  entertainment                    DVD review: I, Robot
# 506  entertainment       Wine comedy up for six film gongs
# 507  entertainment         Willis sues over movie 'injury'
# 508  entertainment       Foxx and Swank take actors awards
# 509  entertainment           Uganda bans Vagina Monologues
# 510  entertainment        Aviator 'creator' in Oscars snub
#
#                                                     tf
# 0    {u'founder': 1, u'obligations': 1, u'money': 1...
# 1    {u'help': 1, u'supported': 1, u'domestic': 1, ...
# 2    {u'managed': 1, u'gradual': 1, u'executive': 1...
# 3    {u'particularly': 2, u'unemployment': 1, u'hal...
# 4    {u'operations': 1, u'assembling': 1, u'conside...
# 5    {u'financial': 1, u'deal': 2, u'distributed': ...
# 6    {u'less': 1, u'advisors': 1, u'years': 1, u'br...
# 7    {u'ignite': 1, u'welcomed': 1, u'executive': 1...
# 8    {u'operations': 2, u'yen': 2, u'increasingly':...
# 9    {u'among': 1, u'google': 2, u'excessive': 1, u...
# 10   {u'proposed': 1, u'teetering': 1, u'money': 1,...
# 11   {u'son': 1, u'saying': 1, u'sentence': 1, u'mo...
# 12   {u'saying': 1, u'meetings': 1, u'global': 1, u...
# 13   {u'already': 1, u'significantly': 1, u'deal': ...
# 14   {u'currently': 2, u'agreed': 1, u'executive': ...
# 15   {u'comment': 1, u'currently': 1, u'less': 1, u...
# 16   {u'help': 2, u'chinese': 3, u'move': 1, u'doll...
# 17   {u'german': 3, u'despite': 1, u'euros': 1, u'd...
# 18   {u'limited': 1, u'office': 1, u'unemployment':...
# 19   {u'houston': 1, u'currently': 1, u'bidding': 1...
# 20   {u'since': 1, u'yen': 2, u'german': 1, u'issue...
# 21   {u'agency': 2, u'chinese': 4, u'agreed': 1, u'...
# 22   {u'surplus': 1, u'office': 1, u'retire': 1, u'...
# 23   {u'gdp': 3, u'smaller': 1, u'economists': 2, u...
# 24   {u'particularly': 1, u'listening': 1, u'oxley'...
# 25   {u'show': 1, u'undervalued': 1, u'astronomical...
# 26   {u'show': 1, u'global': 1, u'expects': 2, u'ex...
# 27   {u'outdoor': 1, u'executive': 1, u'facilities'...
# 28   {u'sentence': 1, u'ebber': 1, u'meetings': 1, ...
# 29   {u'stores': 1, u'competitive': 1, u'battle': 1...
# ..                                                 ...
# 481  {u'art': 1, u'moore': 1, u'norway': 1, u'text'...
# 482  {u'limited': 1, u'responsible': 1, u'office': ...
# 483  {u'thomas': 1, u'leigh': 1, u'chances': 1, u'h...
# 484  {u'among': 1, u'charles': 2, u'dollar': 3, u'a...
# 485  {u'sergei': 1, u'monte': 1, u'cincinnati': 1, ...
# 486  {u'ignite': 1, u'exams': 2, u'help': 1, u'less...
# 487  {u'theron': 1, u'leigh': 1, u'leicester': 1, u...
# 488  {u'saying': 1, u'six': 1, u'office': 4, u'defe...
# 489  {u'shot': 2, u'show': 3, u'september': 1, u'qu...
# 490  {u'jason': 1, u'show': 2, u'guided': 1, u'dica...
# 491  {u'less': 1, u'years': 1, u'prince': 4, u'fift...
# 492  {u'despite': 1, u'soldiers': 1, u'still': 1, u...
# 493  {u'metallica': 1, u'catalina': 1, u'madsen': 1...
# 494  {u'dicaprio': 1, u'dollar': 1, u'trade': 1, u'...
# 495  {u'coach': 1, u'shot': 1, u'office': 3, u'doll...
# 496  {u'shot': 1, u'contemporary': 3, u'storey': 1,...
# 497  {u'roi': 1, u'radio': 1, u'venice': 1, u'le': ...
# 498  {u'code': 2, u'ron': 2, u'global': 1, u'actres...
# 499  {u'anyway': 1, u'actress': 1, u'years': 3, u'k...
# 500  {u'office': 3, u'less': 1, u'fable': 1, u'triv...
# 501  {u'detective': 1, u'bomb': 1, u'retire': 1, u'...
# 502  {u'ali': 1, u'scooped': 1, u'profoundly': 1, u...
# 503  {u'shot': 1, u'show': 1, u'actress': 1, u'mana...
# 504  {u'code': 1, u'cameo': 1, u'ron': 1, u'nominat...
# 505  {u'less': 2, u'accurate': 1, u'knightly': 1, u...
# 506  {u'producer': 1, u'young': 1, u'four': 3, u'he...
# 507  {u'comment': 1, u'help': 1, u'office': 1, u'te...
# 508  {u'among': 1, u'charles': 2, u'dollar': 3, u'a...
# 509  {u'impression': 1, u'show': 1, u'money': 1, u'...
# 510  {u'chinese': 1, u'among': 1, u'photo': 1, u'ex...
#
# [511 rows x 3 columns]

# %%
numOfDocuments = files_with_tf_rdd.count()

# %%
#2.e:creating DFt dictionary
#this function implement distinct

# %%
def removeDuplicates (tokens_list):
            
    return list(dict.fromkeys(tokens_list))

# %%
DFt_rdd = files_devide_to_tokens_rdd.map(lambda row: removeDuplicates(row[2]))
DFt_rdd = DFt_rdd.flatMap(lambda row: row).countByValue()
broadcastDFt = sc.broadcast(DFt_rdd)
broadcastDFt.value
# Out:
# defaultdict(int,
#             {u'brownlees': 1,
#              u'yellow': 1,
#              u'four': 81,
#              u'testosterone': 1,
#              u'hanging': 2,
#              u'conjuring': 1,
#              u'cyprus': 1,
#              u'towns': 2,
#              u'payoff': 1,
#              u'increase': 34,
#              u'eligible': 5,
#              u'electricity': 5,
#              u'benitez': 1,
#              u'wizardry': 1,
#              u'originality': 1,
#              u'list': 33,
#              u'lord': 21,
#              u'ioannidis': 6,
#              u'meadows': 2,
#              u'digit': 2,
#              u'heintze': 1,
#              u'kent': 6,
#              u'dynamic': 1,
#              u'regional': 8,
#              u'pierce': 2,
#              u'wimax': 2,
#              u'holyrood': 6,
#              u'stabbed': 2,
#              u'bringing': 13,
#              u'prize': 27,
#              u'wednesday': 41,
#              u'viable': 1,
#              u'raoul': 1,
#              u'hague': 2,
#              u'succession': 2,
#              u'stereotypical': 2,
#              u'commented': 1,
#              u'charter': 1,
#              u'infringed': 2,
#              u'senne': 1,
#              u'rebuilding': 4,
#              u'miller': 3,
#              u'francesco': 2,
#              u'bacon': 1,
#              u'trailblazers': 1,
#              u'bannister': 1,
#              u'second': 89,
#              u'alloway': 1,
#              u'sustaining': 3,
#              u'currie': 1,
#              u'available': 39,
#              u'scraped': 1,
#              u'quite': 24,
#              u'federal': 19,
#              u'errors': 4,
#              u'bittorrent': 3,
#              u'thunder': 1,
#              u'cooking': 1,
#              u'contributed': 4,
#              u'fingers': 1,
#              u'diamound': 1,
#              u'bonuses': 1,
#              u'updike': 1,
#              u'resilient': 1,
#              u'increasing': 9,
#              u'shocks': 2,
#              u'cull': 1,
#              u'specialist': 6,
#              u'misjudged': 1,
#              u'hero': 9,
#              u'avert': 1,
#              u'reporter': 3,
#              u'interrupting': 1,
#              u'affiliates': 1,
#              u'atoms': 1,
#              u'specialise': 1,
#              u'reported': 27,
#              u'china': 19,
#              u'auctioned': 3,
#              u'verdecchia': 1,
#              u'emmerson': 1,
#              u'borrowers': 1,
#              u'kids': 2,
#              u'climbed': 2,
#              u'eastenders': 2,
#              u'unfriendly': 1,
#              u'reports': 30,
#              u'controversy': 14,
#              u'electors': 1,
#              u'lashawn': 1,
#              u'karin': 1,
#              u'spin': 6,
#              u'military': 1,
#              u'cancellation': 1,
#              u'numerical': 1,
#              u'criticism': 4,
#              u'golden': 22,
#              u'projection': 1,
#              u'criticise': 3,
#              u'characterises': 1,
#              u'explained': 9,
#              u'replace': 10,
#              u'brought': 31,
#              u'beneficiaries': 1,
#              u'unanswered': 1,
#              u'stern': 2,
#              u'unit': 18,
#              u'opponents': 7,
#              u'disproportionately': 1,
#              u'spoke': 9,
#              u'browse': 2,
#              u'insecurity': 2,
#              u'handedness': 1,
#              u'occupying': 1,
#              u'panoply': 1,
#              u'music': 28,
#              u'telegraph': 5,
#              u'passport': 4,
#              u'strike': 9,
#              u'heralded': 1,
#              u'sermons': 1,
#              u'stockmarket': 1,
#              u'wishaw': 1,
#              u'paperwork': 1,
#              u'holy': 3,
#              u'relax': 3,
#              u'successful': 12,
#              u'benefiting': 3,
#              u'pelletier': 1,
#              u'yahoo': 7,
#              u'hurt': 8,
#              u'glass': 1,
#              u'holm': 1,
#              u'midst': 1,
#              u'hold': 25,
#              u'dot': 1,
#              u'circumstances': 9,
#              u'intake': 1,
#              u'xdance': 1,
#              u'locked': 4,
#              u'kampala': 1,
#              u'kosslick': 1,
#              u'pursue': 1,
#              u'famed': 3,
#              u'accomplishment': 2,
#              u'plunged': 2,
#              u'rulings': 1,
#              u'temperatures': 2,
#              u'soundbite': 1,
#              u'burnett': 1,
#              u'revenues': 10,
#              u'example': 20,
#              u'spennymoor': 1,
#              u'melons': 1,
#              u'finalists': 2,
#              u'household': 4,
#              u'sidefooting': 1,
#              u'dragons': 1,
#              u'currency': 5,
#              u'collaborate': 1,
#              u'reviewing': 1,
#              u'want': 78,
#              u'cookers': 1,
#              u'absolute': 3,
#              u'livened': 1,
#              u'provincial': 1,
#              u'turn': 28,
#              u'travel': 4,
#              u'damage': 6,
#              u'revisit': 1,
#              u'machine': 10,
#              u'hot': 6,
#              u'playback': 1,
#              u'hop': 1,
#              u'significance': 2,
#              u'audi': 1,
#              u'void': 2,
#              u'wolfram': 1,
#              u'gaming': 15,
#              u'barbra': 1,
#              u'uselessness': 1,
#              u'utilise': 1,
#              u'funny': 3,
#              u'stravinsky': 1,
#              u'makarov': 1,
#              u'modest': 7,
#              u'spates': 2,
#              u'destined': 1,
#              u'sentencing': 1,
#              u'types': 5,
#              u'opted': 6,
#              u'lukashov': 1,
#              u'effective': 8,
#              u'helsinki': 8,
#              u'wins': 18,
#              u'youths': 1,
#              u'romped': 1,
#              u'deutsche': 5,
#              u'fictional': 3,
#              u'thoday': 1,
#              u'keeps': 2,
#              u'democratic': 5,
#              u'wind': 2,
#              u'wine': 9,
#              u'afterwards': 3,
#              u'feedback': 5,
#              u'welcomed': 11,
#              u'dreamed': 1,
#              u'reforms': 12,
#              u'vary': 3,
#              u'partnered': 1,
#              u'barclays': 1,
#              u'barnet': 1,
#              u'stockpiles': 2,
#              u'fetched': 2,
#              u'rewarded': 1,
#              u'owens': 1,
#              u'welcomes': 1,
#              u'fit': 14,
#              u'cips': 1,
#              u'rankings': 5,
#              u'fix': 4,
#              u'striking': 1,
#              u'auditors': 3,
#              u'survivors': 2,
#              u'malley': 1,
#              u'vast': 11,
#              u'internationals': 1,
#              u'wales': 20,
#              u'hidden': 9,
#              u'easier': 16,
#              u'glorify': 1,
#              u'corridor': 1,
#              u'lambert': 3,
#              u'slate': 1,
#              u'vouchers': 2,
#              u'enrico': 2,
#              u'effects': 10,
#              u'schools': 16,
#              u'township': 1,
#              u'sixteen': 1,
#              u'silver': 22,
#              u'competitiveness': 6,
#              u'rumour': 1,
#              u'represents': 9,
#              u'queues': 1,
#              u'debut': 22,
#              u'barton': 1,
#              u'arron': 1,
#              u'telekom': 1,
#              u'skills': 13,
#              u'spotless': 3,
#              u'timewarner': 1,
#              u'expectancy': 2,
#              u'whim': 1,
#              u'financial': 35,
#              u'reputedly': 1,
#              u'woes': 1,
#              u'series': 36,
#              u'mda': 1,
#              u'spider': 2,
#              u'solution': 7,
#              u'contracting': 1,
#              u'featherboy': 1,
#              u'mcdonagh': 1,
#              u'fortnight': 3,
#              u'substantially': 3,
#              u'laboratory': 7,
#              u'allay': 1,
#              u'tricked': 1,
#              u'xp': 1,
#              u'whip': 2,
#              u'rt': 2,
#              u'recognising': 3,
#              u'inaccurate': 4,
#              u'sms': 1,
#              u'george': 15,
#              u'rd': 1,
#              u'encourage': 10,
#              u'adapt': 1,
#              u'engineer': 2,
#              u'strategist': 4,
#              u'rj': 1,
#              u'foundation': 7,
#              u'clarence': 1,
#              u'assured': 3,
#              u'dracula': 2,
#              u'threatened': 6,
#              u'given': 76,
#              u'managerial': 1,
#              u'necessarily': 5,
#              u'telecoms': 8,
#              u'crowned': 3,
#              u'sensors': 1,
#              u'obstructing': 1,
#              u'gameplay': 1,
#              u'metallica': 1,
#              u'enormous': 11,
#              u'saha': 1,
#              u'shelves': 1,
#              u'ato': 1,
#              u'mcqueen': 1,
#              u'heading': 6,
#              u'silicon': 3,
#              u'ministries': 3,
#              u'shipped': 3,
#              u'levels': 21,
#              u'speedy': 1,
#              u'competed': 4,
#              u'mccafferty': 1,
#              u'markos': 3,
#              u'speeds': 5,
#              u'juergen': 1,
#              u'popularise': 2,
#              u'nigel': 2,
#              u'steroids': 5,
#              u'naude': 1,
#              u'subtlety': 1,
#              u'channels': 6,
#              u'wash': 2,
#              u'instruct': 1,
#              u'pulsar': 1,
#              u'clarity': 4,
#              u'sutherland': 1,
#              u'carfax': 1,
#              u'seizures': 1,
#              u'sparkassen': 1,
#              u'olds': 5,
#              u'basketball': 1,
#              u'service': 58,
#              u'similarly': 3,
#              u'lawsuits': 5,
#              u'engagement': 8,
#              u'rong': 1,
#              u'cooling': 2,
#              u'tango': 1,
#              u'ruins': 1,
#              u'needed': 45,
#              u'master': 4,
#              u'listed': 5,
#              u'livelihoods': 2,
#              u'gilbert': 1,
#              u'legs': 3,
#              u'bitter': 1,
#              u'ranging': 7,
#              u'listen': 6,
#              u'danish': 1,
#              u'rewards': 5,
#              u'collapse': 3,
#              u'geneva': 1,
#              u'bounty': 1,
#              u'expunged': 1,
#              u'wisdom': 1,
#              u'defaulted': 1,
#              u'masala': 1,
#              u'positively': 2,
#              u'carrick': 1,
#              u'ahmed': 2,
#              u'zatoichi': 1,
#              u'showed': 29,
#              u'elegant': 1,
#              u'coward': 1,
#              u'tree': 1,
#              u'whinging': 1,
#              u'nations': 16,
#              u'project': 34,
#              u'idle': 2,
#              u'endure': 1,
#              u'feeling': 11,
#              u'acquisition': 3,
#              u'trev': 1,
#              u'acclaim': 1,
#              u'willingness': 1,
#              u'movabletype': 1,
#              u'runner': 14,
#              u'boston': 9,
#              u'spectrum': 3,
#              u'corny': 1,
#              u'dozen': 3,
#              u'doore': 1,
#              u'affairs': 25,
#              u'implemented': 5,
#              u'releases': 3,
#              u'cyrillic': 1,
#              u'paramedics': 1,
#              u'responsible': 15,
#              u'eagerly': 1,
#              u'connelly': 1,
#              u'recommended': 8,
#              u'causing': 5,
#              u'absorbed': 1,
#              u'doors': 4,
#              u'greenback': 1,
#              u'shipments': 2,
#              u'napsterization': 1,
#              u'transactions': 3,
#              u'thrilled': 3,
#              u'object': 1,
#              u'wells': 3,
#              u'victoria': 2,
#              u'carragher': 1,
#              u'landmark': 6,
#              u'hushing': 1,
#              u'mouth': 1,
#              u'overcapacity': 1,
#              u'letter': 6,
#              u'conceded': 3,
#              u'drought': 1,
#              u'thriller': 8,
#              u'initiator': 1,
#              u'clearance': 4,
#              u'episode': 5,
#              u'grove': 1,
#              u'professor': 14,
#              u'camp': 11,
#              u'rabah': 2,
#              u'tech': 10,
#              u'howl': 3,
#              u'derbyshire': 1,
#              u'came': 67,
#              u'marvel': 1,
#              u'saying': 47,
#              u'signatures': 1,
#              u'bomb': 7,
#              u'powerpage': 1,
#              u'gordievsky': 1,
#              u'meetings': 7,
#              u'advisors': 2,
#              u'nominated': 22,
#              u'prix': 18,
#              u'reschedule': 1,
#              u'qaeda': 1,
#              u'saga': 2,
#              u'participate': 2,
#              u'hungary': 1,
#              u'tempted': 1,
#              u'cheaply': 1,
#              u'lessons': 6,
#              u'apace': 1,
#              u'busy': 4,
#              u'layout': 2,
#              u'louise': 3,
#              u'headline': 1,
#              u'menu': 2,
#              u'gallas': 3,
#              u'pawel': 1,
#              u'bust': 2,
#              u'rico': 1,
#              u'bush': 13,
#              u'rick': 2,
#              u'rich': 9,
#              u'foolishly': 1,
#              u'longhorn': 1,
#              u'rice': 2,
#              u'memoir': 1,
#              u'incredibles': 3,
#              u'caribs': 1,
#              u'plate': 1,
#              u'godzilla': 2,
#              u'rains': 1,
#              u'iata': 1,
#              u'giggs': 2,
#              u'denounce': 1,
#              u'valente': 3,
#              u'pocket': 5,
#              u'lenders': 1,
#              u'altogether': 3,
#              u'net': 44,
#              u'societies': 1,
#              u'autistic': 1,
#              u'textbooks': 3,
#              u'expanding': 7,
#              u'dipping': 2,
#              u'maciej': 1,
#              u'patch': 5,
#              u'greene': 8,
#              u'colen': 1,
#              u'saud': 1,
#              u'release': 28,
#              u'unpatched': 2,
#              u'saul': 1,
#              u'respond': 6,
#              u'pioneering': 1,
#              u'blew': 2,
#              u'mandatory': 2,
#              u'disaster': 8,
#              u'fair': 18,
#              u'heirloom': 1,
#              u'branding': 1,
#              u'niche': 2,
#              u'recruit': 1,
#              u'result': 40,
#              u'fail': 10,
#              u'majeed': 1,
#              u'tyndall': 1,
#              u'hammer': 2,
#              u'best': 108,
#              u'bba': 1,
#              u'sedans': 2,
#              u'explodes': 1,
#              u'campaigners': 5,
#              u'ambitions': 9,
#              u'lots': 7,
#              u'rings': 8,
#              u'registration': 1,
#              u'pressures': 3,
#              u'score': 5,
#              u'melissa': 1,
#              u'mel': 3,
#              u'scorn': 1,
#              u'pilloried': 1,
#              u'pirate': 2,
#              u'preserve': 1,
#              u'wage': 3,
#              u'tapsfield': 1,
#              u'extend': 6,
#              u'nature': 9,
#              u'rolled': 2,
#              u'felony': 2,
#              u'aesthetic': 1,
#              u'bioware': 1,
#              u'heists': 2,
#              u'extent': 4,
#              u'carbon': 1,
#              u'debt': 15,
#              u'tyranny': 1,
#              u'patented': 1,
#              u'accident': 12,
#              u'moazzam': 1,
#              u'triggers': 1,
#              u'country': 91,
#              u'adapter': 1,
#              u'readers': 11,
#              u'pitt': 3,
#              u'sanitise': 1,
#              u'stuttgart': 4,
#              u'estates': 1,
#              u'planned': 18,
#              u'logic': 1,
#              u'login': 4,
#              u'argue': 7,
#              u'adapted': 6,
#              u'asked': 36,
#              u'eradicate': 2,
#              u'ofsted': 1,
#              u'honouring': 4,
#              u'irresponsible': 4,
#              u'mistiming': 1,
#              u'cult': 3,
#              u'unprotected': 4,
#              u'portsmouth': 1,
#              u'exel': 1,
#              u'pregnancy': 1,
#              u'panagiotis': 1,
#              u'jeered': 1,
#              u'airbus': 3,
#              u'rangers': 1,
#              u'union': 40,
#              u'criticised': 19,
#              u'advert': 3,
#              u'much': 94,
#              u'stadium': 5,
#              u'privilege': 1,
#              u'criticises': 2,
#              u'norvasc': 1,
#              u'incompetent': 1,
#              u'deportations': 1,
#              u'testimonies': 1,
#              u'natured': 1,
#              u'life': 59,
#              u'homeland': 2,
#              u'eastern': 7,
#              u'worker': 3,
#              u'wish': 9,
#              u'dave': 4,
#              u'lift': 8,
#              u'reno': 1,
#              u'chile': 2,
#              u'doubts': 1,
#              u'worked': 20,
#              u'dutronc': 1,
#              u'diverted': 1,
#              u'commerce': 6,
#              u'gritty': 2,
#              u'presidency': 1,
#              u'organisers': 12,
#              u'professionally': 3,
#              u'employ': 4,
#              u'gerhard': 3,
#              u'flooding': 1,
#              u'played': 22,
#              u'toolkit': 1,
#              u'player': 18,
#              u'levied': 1,
#              u'madonna': 2,
#              u'marja': 1,
#              u'isinbayeva': 5,
#              u'trusted': 1,
#              u'memorial': 2,
#              u'dhl': 1,
#              u'cheung': 1,
#              u'taped': 1,
#              u'things': 30,
#              u'format': 3,
#              u'rebellion': 1,
#              u'eldridge': 1,
#              u'haiti': 1,
#              u'split': 6,
#              u'elliott': 2,
#              u'principals': 2,
#              u'emphatic': 1,
#              u'european': 88,
#              u'fairly': 5,
#              u'khomenei': 1,
#              u'effortlessly': 1,
#              u'pontiac': 1,
#              u'inadvertently': 4,
#              u'permit': 1,
#              u'tops': 5,
#              u'workforce': 4,
#              u'photographers': 2,
#              u'boiler': 1,
#              u'ownership': 8,
#              u'pioneers': 1,
#              u'josep': 1,
#              u'tune': 3,
#              u'allahgreen': 4,
#              u'intrusion': 1,
#              u'echoed': 1,
#              u'climber': 1,
#              u'academic': 4,
#              u'academie': 1,
#              u'leoncia': 2,
#              u'inked': 1,
#              u'opinions': 3,
#              u'bellow': 1,
#              u'ucas': 1,
#              u'distribute': 7,
#              u'rotated': 1,
#              u'disguise': 1,
#              u'financially': 3,
#              u'birmingham': 22,
#              u'shading': 1,
#              u'digitally': 1,
#              u'plight': 2,
#              u'portrayed': 1,
#              u'tiscali': 2,
#              u'previous': 39,
#              u'alun': 1,
#              u'enters': 1,
#              u'campaign': 30,
#              u'phillips': 5,
#              u'zanussi': 1,
#              u'ease': 2,
#              u'bnp': 2,
#              u'advancement': 2,
#              u'macdonald': 1,
#              u'collections': 1,
#              u'innocent': 6,
#              u'prison': 10,
#              u'east': 15,
#              u'hat': 1,
#              u'casually': 1,
#              u'osman': 1,
#              u'hint': 2,
#              u'survival': 2,
#              u'disagreement': 1,
#              u'possible': 39,
#              u'possibly': 6,
#              u'guinevere': 1,
#              u'gridlock': 1,
#              u'birth': 3,
#              u'ratcheting': 2,
#              u'scoreline': 1,
#              u'shadow': 19,
#              u'unique': 3,
#              u'massively': 3,
#              u'occurring': 1,
#              u'desire': 9,
#              u'psychological': 1,
#              u'steadily': 2,
#              u'bobby': 2,
#              u'seaside': 1,
#              u'alice': 3,
#              u'irresistibility': 1,
#              u'remind': 2,
#              u'pavement': 1,
#              u'steps': 7,
#              u'stylised': 1,
#              u'sebastian': 1,
#              u'unabashedly': 2,
#              u'attorney': 3,
#              u'right': 66,
#              u'old': 86,
#              u'creek': 1,
#              u'crowd': 5,
#              u'people': 180,
#              u'czech': 4,
#              u'deluge': 1,
#              u'pyongyang': 1,
#              u'crown': 10,
#              u'topping': 3,
#              u'naoki': 1,
#              u'hoover': 1,
#              u'recognise': 12,
#              u'bifa': 1,
#              u'saumarez': 1,
#              u'consensus': 2,
#              u'bottom': 4,
#              u'fox': 6,
#              u'creative': 7,
#              u'repression': 1,
#              u'umd': 1,
#              u'disheartened': 1,
#              u'fog': 2,
#              u'treadmill': 1,
#              u'yorks': 1,
#              u'stefan': 1,
#              u'marquez': 1,
#              u'brigades': 1,
#              u'shifting': 2,
#              u'starring': 27,
#              u'rhona': 1,
#              u'losing': 6,
#              u'memorable': 1,
#              u'manufacturing': 8,
#              u'shaken': 2,
#              u'marketers': 1,
#              u'dollars': 2,
#              u'citizens': 9,
#              u'entrants': 2,
#              u'bicentennial': 1,
#              u'albee': 1,
#              u'importantly': 1,
#              u'lacked': 3,
#              u'palestinians': 1,
#              u'slightly': 12,
#              u'eightieth': 1,
#              u'raised': 26,
#              u'statements': 6,
#              u'facility': 1,
#              u'mbe': 1,
#              u'marshall': 1,
#              u'stormed': 7,
#              u'son': 5,
#              u'presenters': 5,
#              u'sos': 1,
#              u'magazines': 1,
#              u'raises': 2,
#              u'soy': 1,
#              u'sox': 1,
#              u'reducing': 9,
#              u'defendants': 1,
#              u'jugnot': 2,
#              u'panorama': 1,
#              u'support': 49,
#              u'halle': 1,
#              u'width': 1,
#              u'jerwood': 1,
#              u'greatness': 1,
#              u'resulted': 1,
#              u'call': 23,
#              u'medallists': 2,
#              u'icon': 4,
#              u'halls': 1,
#              u'launching': 5,
#              u'therefore': 6,
#              u'londoner': 1,
#              u'offer': 42,
#              u'fascination': 1,
#              u'paypal': 1,
#              u'talents': 1,
#              u'encarta': 1,
#              u'understandable': 2,
#              u'safeguard': 1,
#              u'verdi': 1,
#              u'congratulations': 2,
#              u'inside': 14,
#              u'islands': 3,
#              u'greenfairydotcom': 1,
#              u'devices': 14,
#              u'dominicans': 1,
#              u'aycliffe': 1,
#              u'idol': 2,
#              u'unanimous': 2,
#              u'pesos': 1,
#              u'smashed': 5,
#              u'palm': 2,
#              u'panels': 1,
#              u'pricing': 3,
#              u'passenger': 3,
#              u'adopt': 3,
#              u'proved': 10,
#              u'sight': 2,
#              u'barrymore': 1,
#              u'implications': 4,
#              u'disclosing': 1,
#              u'textbook': 3,
#              u'eloy': 1,
#              u'somebody': 2,
#              u'proves': 6,
#              u'exist': 2,
#              u'accounting': 6,
#              u'mrs': 4,
#              u'ericsson': 4,
#              u'dealer': 1,
#              u'negotiations': 8,
#              u'supporters': 8,
#              u'crutches': 1,
#              u'protested': 3,
#              u'relay': 14,
#              u'eventual': 2,
#              u'floor': 1,
#              u'populations': 1,
#              u'cambodia': 2,
#              u'flood': 2,
#              u'underfed': 1,
#              u'republic': 9,
#              u'obliges': 2,
#              u'ambitious': 4,
#              u'brings': 6,
#              u'ferrari': 1,
#              u'developers': 12,
#              u'roll': 6,
#              u'soho': 1,
#              u'hereby': 2,
#              u'intend': 1,
#              u'models': 12,
#              u'devos': 1,
#              u'conservatively': 1,
#              u'investec': 1,
#              u'invested': 3,
#              u'romola': 1,
#              u'rolling': 4,
#              u'explosions': 2,
#              u'congested': 1,
#              u'dunst': 1,
#              u'fonetography': 1,
#              u'scala': 1,
#              u'sniffed': 1,
#              u'idns': 1,
#              u'cristie': 1,
#              u'pet': 1,
#              u'kgb': 1,
#              u'time': 169,
#              u'push': 12,
#              u'overturned': 4,
#              u'detective': 1,
#              u'irrigation': 1,
#              u'cincinnati': 1,
#              u'chain': 4,
#              u'activated': 1,
#              u'mblox': 1,
#              u'avalanche': 1,
#              u'jarring': 2,
#              u'chair': 4,
#              u'hole': 6,
#              u'venice': 5,
#              u'amplification': 1,
#              u'rousing': 1,
#              u'freelance': 1,
#              u'recurrence': 1,
#              u'behave': 1,
#              u'veb': 1,
#              u'oversight': 1,
#              u'ramrodded': 1,
#              u'recipient': 2,
#              u'downloading': 5,
#              u'woodley': 1,
#              u'whodunit': 1,
#              u'directorial': 1,
#              u'recipe': 1,
#              u'bulletin': 3,
#              u'consolidation': 4,
#              u'choice': 20,
#              u'pele': 1,
#              u'embark': 1,
#              u'morally': 2,
#              u'stays': 5,
#              u'justfor': 1,
#              u'launchers': 1,
#              u'exact': 4,
#              u'minute': 15,
#              u'epic': 11,
#              u'tear': 1,
#              u'cameo': 1,
#              u'hibernian': 1,
#              u'leave': 16,
#              u'solved': 2,
#              u'holliday': 1,
#              u'settle': 11,
#              u'subway': 1,
#              u'team': 41,
#              u'speculation': 9,
#              u'ealing': 1,
#              u'teag': 1,
#              u'unaware': 5,
#              u'prevent': 17,
#              u'spiritual': 1,
#              u'blade': 3,
#              u'findings': 6,
#              u'trails': 1,
#              u'computerandvideogames': 1,
#              u'sign': 15,
#              u'heavyweight': 1,
#              u'shirts': 1,
#              u'headset': 1,
#              u'educate': 1,
#              u'elton': 1,
#              u'movies': 19,
#              u'takashi': 2,
#              u'abdullah': 1,
#              u'commenee': 1,
#              u'current': 52,
#              u'waarschuwingsdienst': 1,
#              u'falling': 15,
#              u'ground': 13,
#              u'celebrates': 1,
#              u'illegally': 9,
#              u'drafted': 2,
#              u'jury': 6,
#              u'honour': 9,
#              u'funeral': 1,
#              u'gershon': 2,
#              u'lange': 1,
#              u'understanding': 6,
#              u'upgrade': 5,
#              u'juri': 2,
#              u'yards': 3,
#              u'address': 11,
#              u'alone': 14,
#              u'along': 19,
#              u'dwindling': 1,
#              u'momentous': 1,
#              u'passengers': 6,
#              u'neville': 2,
#              u'plunges': 1,
#              u'redemption': 1,
#              u'brilliant': 1,
#              u'impacted': 1,
#              u'shopaholics': 1,
#              u'studied': 1,
#              u'funded': 4,
#              u'commonly': 4,
#              u'queue': 2,
#              u'accomplished': 3,
#              u'myers': 1,
#              u'studies': 11,
#              u'influx': 1,
#              u'instat': 1,
#              u'tasks': 5,
#              u'love': 13,
#              u'confidentiality': 2,
#              u'prefer': 7,
#              u'logical': 2,
#              u'matsuoka': 1,
#              u'fake': 4,
#              u'relating': 5,
#              u'sky': 9,
#              u'undergone': 1,
#              u'henri': 2,
#              u'working': 45,
#              u'perished': 1,
#              u'positive': 29,
#              u'angry': 6,
#              u'predictions': 5,
#              u'tightly': 1,
#              u'anatomical': 1,
#              u'imaginations': 1,
#              u'cherished': 1,
#              u'ballymena': 3,
#              u'opposed': 8,
#              u'wondering': 1,
#              u'films': 48,
#              u'scope': 2,
#              u'kechiche': 2,
#              u'prosecutor': 2,
#              u'loving': 1,
#              u'introducing': 2,
#              u'alastair': 3,
#              u'afford': 9,
#              u'apparent': 5,
#              u'reprise': 1,
#              u'validity': 2,
#              u'stressing': 1,
#              u'sierra': 2,
#              u'visual': 3,
#              u'everywhere': 2,
#              u'scratches': 1,
#              u'behalf': 11,
#              u'valued': 7,
#              u'sorrell': 1,
#              u'anything': 18,
#              u'titanium': 1,
#              u'scholes': 2,
#              u'heineken': 1,
#              u'originally': 7,
#              u'overloaded': 1,
#              u'abortion': 2,
#              u'privy': 1,
#              ...})

# %%
#2.f Creating Vector table

# %%
vector_size = len(broadcastDFt.value.keys())

# %%
#this function get TFt dictionary of a document
#using the global DFt dictionary
#this function create the vector of the document as a list of float
#every cell represent coordinate for term t and the value is equal to:
#
#vector[i] = (1 + log(TFtd,10)) * log(numOfDocuments / DFt)  if TFtd > 0
#            0                                               Else
import math
def vectorize(TFt_dict):
    keys = broadcastDFt.value.keys()
    numOfTokens = len(keys)
    vector = [0]*numOfTokens
    i=0
    for token in keys:
        vector[i] = TFt_dict.get(token,0)
        if vector[i] != 0:
            #in case th tf for this token is bigger from 0 than we calculate the weight
            vector[i] = (1 + math.log(vector[i], 10)) * (math.log(numOfDocuments/ broadcastDFt.value.get(token), 10))
        i = i+1
    return vector

# %%
#this function just calculate the length of the vector and normalize the vector
def normalize(vector):
    sumOfPow2 = 0
    for i in vector:
        sumOfPow2 = sumOfPow2 + i*i
    vectorLength = math.sqrt(sumOfPow2)
    norm_vector = map(lambda x: x / vectorLength, vector)
    return norm_vector

# %%
#here we create table that every row: [category, article name, vector]
files_with_vectors_rdd = files_with_tf_rdd.map(lambda row: [row[0],row[1],vectorize(row[2])])
files_with_vectors_rdd.toDF(["category", "article_name", "vector"]).show(5)
# Out:
# +--------+--------------------+--------------------+
# |category|        article_name|              vector|
# +--------+--------------------+--------------------+
# |business|Yukos unit buyer ...|[0, 0, 0, 0, 0, 0...|
# |business|Soaring oil 'hits...|[0, 0, 0, 0, 0, 0...|
# |business|Weak dollar hits ...|[0, 0, 0, 0, 0, 0...|
# |business|Palestinian econo...|[0, 0,, 0, 0, 0, ...|
# |business|BMW drives record...|[0, 0, 0, 0, 0, 0...|
# +--------+--------------------+--------------------+
# only showing top 5 rows

# %%
#here we normalize the vector for every document

# %%
files_with_norm_vectors_rdd = files_with_vectors_rdd.map(lambda row: [row[0],row[1],normalize(row[2])])
files_with_norm_vectors_rdd.toDF(["category", "article_name", "norm_vector"]).show(5)
# Out:
# +--------+--------------------+--------------------+
# |category|        article_name|         norm_vector|
# +--------+--------------------+--------------------+
# |business|Yukos unit buyer ...|[0.0, 0.0, 0.0, 0...|
# |business|Soaring oil 'hits...|[0.0, 0.0, 0.0, 0...|
# |business|Weak dollar hits ...|[0.0, 0.0, 0.0, 0...|
# |business|Palestinian econo...|[0.0, 0.0, 0.0542...|
# |business|BMW drives record...|[0.0, 0.0, 0.0, 0...|
# +--------+--------------------+--------------------+
# only showing top 5 rows

# %%
#3 Finding for every document the 5 documents most similar

# %%
files_with_norm_vectors_rdd_broadcast = sc.broadcast(files_with_norm_vectors_rdd.collect())

# %%
def calculateCos(v1,v2):
    sizeV = len(v1)
    i = 0
    cos = 0
    while(i<sizeV):
        cos = cos + v1[i] * v2[i]
        i = i+1
    return cos

# %%
def confrontListOf5(row,cos,top_5_list):
    distance = abs(1-cos)
    top_5_list.append([row[0],row[1],cos,distance])
    if len(top_5_list)>5:
        maxD = -1
        maxRow = None
        for i in top_5_list:
            if(i[3]>maxD):
                maxD = i[3]
                maxRow = i
        top_5_list.remove(maxRow)
    return top_5_list

# %%
def findTopClose5(row):
    top_5_list = []
    counter=0
    for i in files_with_norm_vectors_rdd_broadcast.value:
        if i[1] == row[1]:
            continue
        cos = calculateCos(row[2],i[2])
        top_5_list = confrontListOf5(i,cos,top_5_list)
        print("iteration ",counter," with/",row[1])
        counter = counter +1
    row[2] = map(lambda x: x[:-1],top_5_list)
    print("finish with/",row[1])
    return row

# %%
top5_close_article_rdd = files_with_norm_vectors_rdd.map(findTopClose5)

top5_close_article_rdd.take(100)
# Out:
# [[u'business',
#   u'Yukos unit buyer faces loan claim',
#   [[u'business', u'Yukos accused of lying to court', 0.28030461610659074],
#    [u'business', u'Parmalat to return to stockmarket', 0.09071300941278213],
#    [u'business', u'China had role in Yukos split-up', 0.3275699602673347],
#    [u'business', u'Russia gets investment blessing', 0.11657800664375875],
#    [u'business', u'Yukos loses US bankruptcy battle', 0.22488672667476062]]],
#  [u'business',
#   u"Soaring oil 'hits world economy'",
#   [[u'business', u'Industrial output falls in Japan', 0.15403681919859052],
#    [u'business', u'German business confidence slides', 0.1287132265420408],
#    [u'business', u'Japan economy slides to recession', 0.15576625073183353],
#    [u'business', u'Strong demand triggers oil rally', 0.10383409403220573],
#    [u'business', u"IMF 'cuts' German growth estimate", 0.1885405513233295]]],
#  [u'business',
#   u'Weak dollar hits Reuters',
#   [[u'business', u'Parmalat boasts doubled profits', 0.08531322385112404],
#    [u'business', u"High fuel prices hit BA's profits", 0.11266918658444877],
#    [u'business', u'Ad sales boost Time Warner profit', 0.10517867006769777],
#    [u'business', u"Wembley firm won't make a profit", 0.09319762402414768],
#    [u'business', u"Ad firm WPP's profits surge 15%", 0.08628371244322129]]],
#  [u'business',
#   u'Palestinian economy in decline',
#   [[u'business', u'Jobs growth still slow in the US', 0.09788751374625806],
#    [u'business', u'US economy shows solid GDP growth', 0.08632684621464976],
#    [u'business', u'Industrial output falls in Japan', 0.07441110319906549],
#    [u'business', u'German business confidence slides', 0.07655246013640221],
#    [u'business', u'China keeps tight rein on credit', 0.0724330286700074]]],
#  [u'business',
#   u'BMW drives record sales in Asia',
#   [[u'business', u'Peugeot deal boosts Mitsubishi', 0.08506132331353411],
#    [u'business', u'Cars pull down US retail figures', 0.09122233568783639],
#    [u'business', u'BMW to recall faulty diesel cars', 0.17895229864902062],
#    [u'business', u'BMW cash to fuel Mini production', 0.1726958762493557],
#    [u'business', u'Bad weather hits Nestle sales', 0.08775679919769763]]],
#  [u'business',
#   u'Metlife buys up Citigroup insurer',
#   [[u'business', u'Peugeot deal boosts Mitsubishi', 0.06833922447083134],
#    [u'business', u'China had role in Yukos split-up', 0.06988495428205932],
#    [u'business', u'Ad sales boost Time Warner profit', 0.08185030673847861],
#    [u'business', u'Fiat mulls Ferrari market listing', 0.07475999019537508],
#    [u'business', u'Deutsche Telekom sees mobile gain', 0.0720275054713906]]],
#  [u'business',
#   u'Parmalat boasts doubled profits',
#   [[u'business', u'Weak dollar hits Reuters', 0.08531322385112404],
#    [u'business', u'Parmalat to return to stockmarket', 0.18554631078541098],
#    [u'business', u'Ad sales boost Time Warner profit', 0.09115549342935649],
#    [u'business', u'Deutsche Telekom sees mobile gain', 0.11046748057841586],
#    [u'business', u'Yukos loses US bankruptcy battle', 0.0915137220153347]]],
#  [u'business',
#   u'India widens access to telecoms',
#   [[u'business', u'Iranian MPs threaten mobile deal', 0.07564364027713724],
#    [u'business', u'Hyundai to build new India plant', 0.07985769679500576],
#    [u'business', u'Irish markets reach all-time high', 0.09784598492637535],
#    [u'business', u'India seeks to boost construction', 0.10680831434887228],
#    [u'tech', u"Global digital divide 'narrowing'", 0.06793622272931801]]],
#  [u'business',
#   u'Japanese banking battle at an end',
#   [[u'business', u'Japanese mogul arrested for fraud', 0.12264212957421931],
#    [u'business', u'Peugeot deal boosts Mitsubishi', 0.12243516543290994],
#    [u'business', u'Circuit City gets takeover offer', 0.09283608204286653],
#    [u'business', u"Steel firm 'to cut' 45,000 jobs", 0.07578281268597205],
#    [u'entertainment',
#     u"Howl helps boost Japan's cinemas",
#     0.08377381270948242]]],
#  [u'business',
#   u'Ask Jeeves tips online ad revival',
#   [[u'business', u'Ad sales boost Time Warner profit', 0.18408774286561136],
#    [u'business', u"Wembley firm won't make a profit", 0.085992141604402],
#    [u'tech', u'Microsoft launches its own search', 0.09302399854850416],
#    [u'tech', u'Savvy searchers fail to spot ads', 0.09181101745355272],
#    [u'tech', u'Ask Jeeves joins web log market', 0.10379842713258661]]],
#  [u'business',
#   u'EU aiming to fuel development aid',
#   [[u'business', u'EU ministers to mull jet fuel tax', 0.48885831468035784],
#    [u'business', u'Italy to get economic action plan', 0.09654578271386849],
#    [u'business', u'Air passengers win new EU rights', 0.08005369424586421],
#    [u'business', u"SA unveils 'more for all' budget", 0.09010755871362083],
#    [u'tech', u'Reboot ordered for EU patent law', 0.08055329189825662]]],
#  [u'business',
#   u'Japanese mogul arrested for fraud',
#   [[u'business', u'Japanese banking battle at an end', 0.12264212957421931],
#    [u'business', u'Peugeot deal boosts Mitsubishi', 0.08565717169534162],
#    [u'business', u'Parmalat to return to stockmarket', 0.06594232930765771],
#    [u'business', u'Japan economy slides to recession', 0.07303193413562223],
#    [u'business', u'Fiat mulls Ferrari market listing', 0.06701704638691729]]],
#  [u'business',
#   u'EU ministers to mull jet fuel tax',
#   [[u'business', u'EU aiming to fuel development aid', 0.48885831468035784],
#    [u'business', u'Italy to get economic action plan', 0.09833971536674257],
#    [u'tech', u'New delay hits EU software laws', 0.09738434668615537],
#    [u'politics', u'Nat Insurance to rise, say Tories', 0.08700515065432476],
#    [u'politics', u'Leaders meet over Turkish EU bid', 0.11233646444582174]]],
#  [u'business',
#   u'Burren awarded Egyptian contracts',
#   [[u'business', u'Metlife buys up Citigroup insurer', 0.054021166176033114],
#    [u'business', u'Argentina, Venezuela in oil deal', 0.06899888536703384],
#    [u'business', u"Steel firm 'to cut' 45,000 jobs", 0.06008749241794923],
#    [u'business', u"India's rupee hits five-year high", 0.054434615585110514],
#    [u'business', u'US crude prices surge above $53', 0.054640672407181165]]],
#  [u'business',
#   u'Telegraph newspapers axe 90 jobs',
#   [[u'business', u"Steel firm 'to cut' 45,000 jobs", 0.06574714938246613],
#    [u'business', u"Rover deal 'may cost 2,000 jobs'", 0.06702165606617291],
#    [u'tech', u"Games firms 'face tough future'", 0.06280016987943458],
#    [u'politics', u'Strike threat over pension plans', 0.06555182561537853],
#    [u'politics', u"Job cuts 'false economy'  - TUC", 0.06255200500901924]]],
#  [u'business',
#   u'Iranian MPs threaten mobile deal',
#   [[u'business', u'India widens access to telecoms', 0.07564364027713724],
#    [u'business', u'Ad sales boost Time Warner profit', 0.07435295711384546],
#    [u'business', u"Turkey-Iran mobile deal 'at risk'", 0.39261745793252933],
#    [u'tech', u'The future in your pocket', 0.07610131413067311],
#    [u'tech', u"'Friends fear' with lost mobiles", 0.06909471998485683]]],
#  [u'business',
#   u'Dollar gains on Greenspan speech',
#   [[u'business', u'Fed chief warning on US deficit', 0.14255307288068156],
#    [u'business', u'US trade gap hits record in 2004', 0.1314093828722476],
#    [u'business', u'Europe blames US over weak dollar', 0.14538596389859282],
#    [u'business', u'India calls for fair trade rules', 0.10657001160646253],
#    [u'business', u"'Strong dollar' call halts slide", 0.14256342171497818]]],
#  [u'business',
#   u'Lufthansa may sue over Bush visit',
#   [[u'business', u"High fuel prices hit BA's profits", 0.07283140838590045],
#    [u'business', u'Air passengers win new EU rights', 0.1497034155198839],
#    [u'business', u'Ryanair in $4bn Boeing plane deal', 0.09299265879877579],
#    [u'business', u'Boeing unveils new 777 aircraft', 0.10392401801943026],
#    [u'politics', u'Protesters plan airport challenge', 0.0717782800208011]]],
#  [u'business',
#   u'Jobs growth still slow in the US',
#   [[u'business', u'Palestinian economy in decline', 0.09788751374625806],
#    [u'business', u'Further rise in UK jobless total', 0.12873323706890408],
#    [u'business', u"Manufacturing recovery 'slowing'", 0.10476256709780195],
#    [u'business', u'Sluggish economy hits German jobs', 0.1054077947991365],
#    [u'business', u"'Strong dollar' call halts slide", 0.10342926412906224]]],
#  [u'business',
#   u'Yukos accused of lying to court',
#   [[u'business', u'Yukos unit buyer faces loan claim', 0.28030461610659074],
#    [u'business', u'China had role in Yukos split-up', 0.247753355244843],
#    [u'business', u'Russia gets investment blessing', 0.13028413623296095],
#    [u'business', u'Yukos loses US bankruptcy battle', 0.3893673997588854],
#    [u'politics', u'Opposition grows to house arrests', 0.0719840465691978]]],
#  [u'business',
#   u'Peugeot deal boosts Mitsubishi',
#   [[u'business', u'Japanese banking battle at an end', 0.12243516543290994],
#    [u'business', u'Hyundai to build new India plant', 0.11406861926792994],
#    [u'business', u'Safety alert as GM recalls cars', 0.11427275647547327],
#    [u'business', u'BMW to recall faulty diesel cars', 0.11682373456646222],
#    [u'business', u'Fiat mulls Ferrari market listing', 0.09867769488566125]]],
#  [u'business',
#   u"Chinese wine tempts Italy's Illva",
#   [[u'business', u'US trade gap hits record in 2004', 0.0699478931531387],
#    [u'business', u'Parmalat to return to stockmarket', 0.0718673663774967],
#    [u'business', u'French wine gets 70m euro top-up', 0.10638326285380562],
#    [u'business', u'Fiat mulls Ferrari market listing', 0.09517564139481004],
#    [u'business', u'China keeps tight rein on credit', 0.07805400253539407]]],
#  [u'business',
#   u'Fed chief warning on US deficit',
#   [[u'business', u'Dollar gains on Greenspan speech', 0.14255307288068156],
#    [u'business', u"'Strong dollar' call halts slide", 0.1284163646677451],
#    [u'business', u"SA unveils 'more for all' budget", 0.09621631730924418],
#    [u'politics', u'Strike threat over pension plans', 0.10236440305115896],
#    [u'politics', u'Brown names 16 March for Budget', 0.11471882243608794]]],
#  [u'business',
#   u'US economy shows solid GDP growth',
#   [[u'business', u'US trade gap hits record in 2004', 0.18863924708317137],
#    [u'business', u'Industrial output falls in Japan', 0.152147674399578],
#    [u'business', u'Japan economy slides to recession', 0.19673872936066883],
#    [u'business', u'India calls for fair trade rules', 0.12511108800574278],
#    [u'business', u'Mixed signals from French economy', 0.13510492678317473]]],
#  [u'business',
#   u'US gives foreign firms extra time',
#   [[u'business', u'Japanese mogul arrested for fraud', 0.06579135478685746],
#    [u'tech', u'New delay hits EU software laws', 0.06399116247731432],
#    [u'politics', u"Campaign 'cold calls' questioned", 0.06478303157038023],
#    [u'politics', u'Brown ally rejects Budget spree', 0.09106947459141007],
#    [u'politics', u"Labour's 'EU propaganda'", 0.05840408065979902]]],
#  [u'business',
#   u'US trade gap hits record in 2004',
#   [[u'business', u'Dollar gains on Greenspan speech', 0.1314093828722476],
#    [u'business', u'US economy shows solid GDP growth', 0.18863924708317137],
#    [u'business', u'Europe blames US over weak dollar', 0.12050948117988766],
#    [u'business', u'Strong demand triggers oil rally', 0.12892516489405373],
#    [u'business', u"'Strong dollar' call halts slide", 0.13902959149045707]]],
#  [u'business',
#   u'Hyundai to build new India plant',
#   [[u'business', u'Peugeot deal boosts Mitsubishi', 0.11406861926792994],
#    [u'business', u'Deadline nears for Fiat-GM deal', 0.08041913278123673],
#    [u'business', u"Rover deal 'may cost 2,000 jobs'", 0.11159735718715351],
#    [u'business', u'BMW cash to fuel Mini production', 0.11178532915288145],
#    [u'business', u"India's rupee hits five-year high", 0.09444392000842919]]],
#  [u'business',
#   u'Electrolux to export Europe jobs',
#   [[u'business', u'Weak dollar hits Reuters', 0.05841854792760579],
#    [u'business', u'Hyundai to build new India plant', 0.06443558822387949],
#    [u'business', u"Steel firm 'to cut' 45,000 jobs", 0.06372168547736684],
#    [u'business', u"Rover deal 'may cost 2,000 jobs'", 0.05618590401597555],
#    [u'tech', u'Nuclear body seeks new tech', 0.07268829125059034]]],
#  [u'business',
#   u'Worldcom ex-boss launches defence',
#   [[u'business', u'Parmalat boasts doubled profits', 0.06530913098513176],
#    [u'business', u"Worldcom boss 'left books alone'", 0.2802024939899977],
#    [u'business', u'Russia gets investment blessing', 0.05673024686652356],
#    [u'business', u'Yukos loses US bankruptcy battle', 0.07769837724268826],
#    [u'tech', u'US peer-to-peer pirates convicted', 0.06273208774045345]]],
#  [u'business',
#   u'Circuit City gets takeover offer',
#   [[u'business', u'Japanese banking battle at an end', 0.09283608204286653],
#    [u'business', u"Chinese wine tempts Italy's Illva", 0.06957637624967802],
#    [u'business', u'Deadline nears for Fiat-GM deal', 0.08053650531487486],
#    [u'business', u'Pernod takeover talk lifts Domecq', 0.06464797927419344],
#    [u'business', u'Takeover rumour lifts Exel shares', 0.10230935696221909]]],
#  [u'business',
#   u'UK Coal plunges into deeper loss',
#   [[u'business', u'Industrial output falls in Japan', 0.06508427242742552],
#    [u'business', u"High fuel prices hit BA's profits", 0.08052418296585269],
#    [u'business', u'BMW cash to fuel Mini production', 0.05290288531859899],
#    [u'business', u'Ryanair in $4bn Boeing plane deal', 0.060383306394283534],
#    [u'business', u'Umbro profits lifted by Euro 2004', 0.06448791180807481]]],
#  [u'business',
#   u'Argentina, Venezuela in oil deal',
#   [[u'business', u'Burren awarded Egyptian contracts', 0.06899888536703384],
#    [u'business', u'UK firm faces Venezuelan land row', 0.12555284201909134],
#    [u'business', u'Argentina closes $102.6bn debt swap', 0.09760460017637836],
#    [u'politics', u'Tsunami debt deal to be announced', 0.06170325212063729],
#    [u'sport', u'UK Athletics agrees new kit deal', 0.05837627685380996]]],
#  [u'business',
#   u"Economy 'stronger than forecast'",
#   [[u'business', u'US economy shows solid GDP growth', 0.11385828249712404],
#    [u'business', u'Industrial output falls in Japan', 0.12050593026370071],
#    [u'business', u'Further rise in UK jobless total', 0.13722521740982818],
#    [u'business', u"IMF 'cuts' German growth estimate", 0.11805438892558417],
#    [u'business', u'Mixed signals from French economy', 0.13628421096389134]]],
#  [u'business',
#   u"Worldcom boss 'left books alone'",
#   [[u'business', u'Yukos accused of lying to court', 0.05577684265507039],
#    [u'business', u'Worldcom ex-boss launches defence', 0.2802024939899977],
#    [u'business', u'Insurance bosses plead guilty', 0.058592919766471775],
#    [u'business', u'Yukos loses US bankruptcy battle', 0.061882444616884406],
#    [u'sport', u'Greek pair attend drugs hearing', 0.05807862554290767]]],
#  [u'business',
#   u'Safety alert as GM recalls cars',
#   [[u'business', u'Peugeot deal boosts Mitsubishi', 0.11427275647547327],
#    [u'business', u'Hyundai to build new India plant', 0.07043916710680086],
#    [u'business', u'Deadline nears for Fiat-GM deal', 0.07322675779631113],
#    [u'business', u'BMW to recall faulty diesel cars', 0.08561488623521903],
#    [u'business', u'Fiat mulls Ferrari market listing', 0.05949567698663952]]],
#  [u'business',
#   u"Call centre users 'lose patience'",
#   [[u'tech', u'Mobile networks seek turbo boost', 0.08045400105075451],
#    [u'tech', u'The future in your pocket', 0.09223970988662838],
#    [u'tech', u'IBM puts cash behind Linux push', 0.07591011338982402],
#    [u'tech', u'Warning over Windows Word files', 0.07770025509179077],
#    [u'tech', u"'Friends fear' with lost mobiles", 0.08046283297720473]]],
#  [u'business',
#   u'Europe blames US over weak dollar',
#   [[u'business', u'Dollar gains on Greenspan speech', 0.14538596389859282],
#    [u'business', u'US trade gap hits record in 2004', 0.12050948117988766],
#    [u'business', u'Industrial output falls in Japan', 0.10511840389810788],
#    [u'business', u"IMF 'cuts' German growth estimate", 0.10192201462466612],
#    [u'business', u"'Strong dollar' call halts slide", 0.24833406857292661]]],
#  [u'business',
#   u'Deadline nears for Fiat-GM deal',
#   [[u'business', u'Peugeot deal boosts Mitsubishi', 0.08484992494015475],
#    [u'business', u'Hyundai to build new India plant', 0.08041913278123673],
#    [u'business', u'Circuit City gets takeover offer', 0.08053650531487486],
#    [u'business', u'Safety alert as GM recalls cars', 0.07322675779631113],
#    [u'business', u'Fiat mulls Ferrari market listing', 0.19684955603411963]]],
#  [u'business',
#   u'Industrial output falls in Japan',
#   [[u'business', u"Soaring oil 'hits world economy'", 0.15403681919859052],
#    [u'business', u'US economy shows solid GDP growth', 0.152147674399578],
#    [u'business', u'German business confidence slides', 0.14548860902497027],
#    [u'business', u'Japan narrowly escapes recession', 0.14645684125489825],
#    [u'business', u'Japan economy slides to recession', 0.18743977977278528]]],
#  [u'business',
#   u"Steel firm 'to cut' 45,000 jobs",
#   [[u'business', u'Japanese banking battle at an end', 0.07578281268597205],
#    [u'business', u"Rover deal 'may cost 2,000 jobs'", 0.07288377560674424],
#    [u'business', u"Wembley firm won't make a profit", 0.07065534766226403],
#    [u'business', u'India seeks to boost construction', 0.07717913167584858],
#    [u'politics', u"Job cuts 'false economy'  - TUC", 0.07240913454423273]]],
#  [u'business',
#   u"Ethiopia's crop production up 24%",
#   [[u'business', u'US economy shows solid GDP growth', 0.05509429045968925],
#    [u'business', u"Steel firm 'to cut' 45,000 jobs", 0.049429484533655185],
#    [u'business', u'FAO warns on impact of subsidies', 0.10931339913027333],
#    [u'business', u'Pernod takeover talk lifts Domecq', 0.043039704630180885],
#    [u'tech', u'Wi-fi web reaches farmers in Peru', 0.045628878531171584]]],
#  [u'business',
#   u'FAO warns on impact of subsidies',
#   [[u'business', u"Ethiopia's crop production up 24%", 0.10931339913027333],
#    [u'business', u'Rich grab half Colombia poor fund', 0.07959617790576881],
#    [u'business', u'French wine gets 70m euro top-up', 0.0851522067680003],
#    [u'business', u'India calls for fair trade rules', 0.11064223913747333],
#    [u'tech', u"Global digital divide 'narrowing'", 0.09163881877405572]]],
#  [u'business',
#   u'Home loan approvals rising again',
#   [[u'business', u"Economy 'stronger than forecast'", 0.07879672204019954],
#    [u'business', u'Industrial output falls in Japan', 0.08886883822368348],
#    [u'business', u'Further rise in UK jobless total', 0.11961100422920591],
#    [u'business', u"High fuel prices hit BA's profits", 0.08492982967537126],
#    [u'business', u'S Korean consumers spending again', 0.11271238529824613]]],
#  [u'business',
#   u'UK firm faces Venezuelan land row',
#   [[u'business', u'Yukos unit buyer faces loan claim', 0.07303588554388589],
#    [u'business', u'Yukos accused of lying to court', 0.05002620503046193],
#    [u'business', u'Argentina, Venezuela in oil deal', 0.12555284201909134],
#    [u'business', u"Steel firm 'to cut' 45,000 jobs", 0.04716536750523559],
#    [u'tech', u'New delay hits EU software laws', 0.04920908471792708]]],
#  [u'business',
#   u'Cars pull down US retail figures',
#   [[u'business', u'Jobs growth still slow in the US', 0.09336730380543691],
#    [u'business', u'US economy shows solid GDP growth', 0.10498383278551339],
#    [u'business', u'Industrial output falls in Japan', 0.11971667988380198],
#    [u'business', u'Further rise in UK jobless total', 0.1234143970958203],
#    [u'business', u'Japan economy slides to recession', 0.09581865188734053]]],
#  [u'business',
#   u'Parmalat to return to stockmarket',
#   [[u'business', u'Yukos unit buyer faces loan claim', 0.09071300941278213],
#    [u'business', u'Parmalat boasts doubled profits', 0.18554631078541098],
#    [u'business', u'Argentina closes $102.6bn debt swap', 0.07605283989464584],
#    [u'business', u'Fiat mulls Ferrari market listing', 0.07351664982246835],
#    [u'business', u'Umbro profits lifted by Euro 2004', 0.07923951329070804]]],
#  [u'business',
#   u'German business confidence slides',
#   [[u'business', u'Industrial output falls in Japan', 0.14548860902497027],
#    [u'business', u'Japan economy slides to recession', 0.14535012908110562],
#    [u'business', u"IMF 'cuts' German growth estimate", 0.13591641379143013],
#    [u'business', u'German growth goes into reverse', 0.27487068080053956],
#    [u'business', u"Manufacturing recovery 'slowing'", 0.13338084878021572]]],
#  [u'business',
#   u'Pernod takeover talk lifts Domecq',
#   [[u'business', u'Parmalat boasts doubled profits', 0.06960896696149467],
#    [u'business', u'Circuit City gets takeover offer', 0.06464797927419344],
#    [u'business', u'Irish markets reach all-time high', 0.06721673035907286],
#    [u'business', u'Bad weather hits Nestle sales', 0.07294303449212547],
#    [u'business', u'Takeover rumour lifts Exel shares', 0.09491434495872718]]],
#  [u'business',
#   u'China had role in Yukos split-up',
#   [[u'business', u'Yukos unit buyer faces loan claim', 0.3275699602673347],
#    [u'business', u'Yukos accused of lying to court', 0.247753355244843],
#    [u'business', u'Strong demand triggers oil rally', 0.1019951305239467],
#    [u'business', u'Russia gets investment blessing', 0.1276181138198169],
#    [u'business', u'Yukos loses US bankruptcy battle', 0.23967535348059651]]],
#  [u'business',
#   u'Further rise in UK jobless total',
#   [[u'business', u'Jobs growth still slow in the US', 0.12873323706890408],
#    [u'business', u"Economy 'stronger than forecast'", 0.13722521740982818],
#    [u'business', u'Industrial output falls in Japan', 0.13557982134957747],
#    [u'business', u"Manufacturing recovery 'slowing'", 0.13087389237978456],
#    [u'business', u'Mixed signals from French economy', 0.12421643265170941]]],
#  [u'business',
#   u'BMW to recall faulty diesel cars',
#   [[u'business', u'BMW drives record sales in Asia', 0.17895229864902062],
#    [u'business', u'Peugeot deal boosts Mitsubishi', 0.11682373456646222],
#    [u'business', u'Safety alert as GM recalls cars', 0.08561488623521903],
#    [u'business', u'BMW cash to fuel Mini production', 0.13492598461977925],
#    [u'tech', u"Xbox power cable 'fire fear'", 0.08910257953897441]]],
#  [u'business',
#   u'Rich grab half Colombia poor fund',
#   [[u'business', u'EU ministers to mull jet fuel tax', 0.0801774133102392],
#    [u'business', u'FAO warns on impact of subsidies', 0.07959617790576881],
#    [u'business', u'Indonesians face fuel price rise', 0.09008502995974427],
#    [u'tech', u"Global digital divide 'narrowing'", 0.09337884367881355],
#    [u'politics', u"Job cuts 'false economy'  - TUC", 0.08924573843174594]]],
#  [u'business',
#   u'Japan turns to beer alternatives',
#   [[u'business', u'Japanese banking battle at an end', 0.057996431171951815],
#    [u'business', u'Peugeot deal boosts Mitsubishi', 0.05418821916574441],
#    [u'business', u"'Strong dollar' call halts slide", 0.05598812685541458],
#    [u'tech', u'Cheaper chip for mobiles', 0.05905873576028445],
#    [u'entertainment',
#     u"Howl helps boost Japan's cinemas",
#     0.05905062368587383]]],
#  [u'business',
#   u'Argentina closes $102.6bn debt swap',
#   [[u'business', u'US economy shows solid GDP growth', 0.0767950530914146],
#    [u'business', u'Argentina, Venezuela in oil deal', 0.09760460017637836],
#    [u'business', u'Parmalat to return to stockmarket', 0.07605283989464584],
#    [u'business', u'Russia gets investment blessing', 0.06928177382581083],
#    [u'politics', u'Tsunami debt deal to be announced', 0.0909925048324697]]],
#  [u'business',
#   u'Indonesians face fuel price rise',
#   [[u'business', u"Soaring oil 'hits world economy'", 0.07442855727395559],
#    [u'business', u'EU ministers to mull jet fuel tax', 0.06966258140941778],
#    [u'business', u'FAO warns on impact of subsidies', 0.07165896895487311],
#    [u'business', u'Rich grab half Colombia poor fund', 0.09008502995974427],
#    [u'business', u"High fuel prices hit BA's profits", 0.08313861023984517]]],
#  [u'business',
#   u'Japan narrowly escapes recession',
#   [[u'business', u'Industrial output falls in Japan', 0.14645684125489825],
#    [u'business', u'German business confidence slides', 0.09722173009918239],
#    [u'business', u'Japan economy slides to recession', 0.2164734538203043],
#    [u'business', u'German growth goes into reverse', 0.09016296730314813],
#    [u'business', u"Manufacturing recovery 'slowing'", 0.09235244337894435]]],
#  [u'business',
#   u"Rover deal 'may cost 2,000 jobs'",
#   [[u'business', u'Peugeot deal boosts Mitsubishi', 0.09285669728987188],
#    [u'business', u'Hyundai to build new India plant', 0.11159735718715351],
#    [u'business', u"Steel firm 'to cut' 45,000 jobs", 0.07288377560674424],
#    [u'business', u'BMW cash to fuel Mini production', 0.18770775445884436],
#    [u'politics', u"Job cuts 'false economy'  - TUC", 0.08090539852166909]]],
#  [u'business',
#   u'Insurance bosses plead guilty',
#   [[u'tech', u'US peer-to-peer pirates convicted', 0.07901277181857638],
#    [u'sport', u'Jones files lawsuit against Conte', 0.06191318456266997],
#    [u'sport', u"Jones medals 'must go if guilty'", 0.08527763305155424],
#    [u'sport', u'Jones files Conte lawsuit', 0.06191318456266997],
#    [u'sport', u'Trial date is set for Balco case', 0.06319271038226873]]],
#  [u'business',
#   u'Japan economy slides to recession',
#   [[u'business', u"Soaring oil 'hits world economy'", 0.15576625073183353],
#    [u'business', u'US economy shows solid GDP growth', 0.19673872936066883],
#    [u'business', u'Industrial output falls in Japan', 0.18743977977278528],
#    [u'business', u'German business confidence slides', 0.14535012908110562],
#    [u'business', u'Japan narrowly escapes recession', 0.2164734538203043]]],
#  [u'business',
#   u'Mexican in US send $16bn home',
#   [[u'business', u'US economy shows solid GDP growth', 0.09347788718540295],
#    [u'business', u'Argentina closes $102.6bn debt swap', 0.06757225873712938],
#    [u'business', u'Russia gets investment blessing', 0.07143291703202316],
#    [u'business', u"'Strong dollar' call halts slide", 0.06444481190252635],
#    [u'tech', u"China 'to overtake US net use'", 0.06989736048126086]]],
#  [u'business',
#   u'Strong demand triggers oil rally',
#   [[u'business', u"Soaring oil 'hits world economy'", 0.10383409403220573],
#    [u'business', u'US trade gap hits record in 2004', 0.12892516489405373],
#    [u'business', u'China had role in Yukos split-up', 0.1019951305239467],
#    [u'business', u'Russia gets investment blessing', 0.08405963325472485],
#    [u'business', u'US crude prices surge above $53', 0.1778391145915154]]],
#  [u'business',
#   u'French wine gets 70m euro top-up',
#   [[u'business', u'EU aiming to fuel development aid', 0.06637207505386637],
#    [u'business', u"Chinese wine tempts Italy's Illva", 0.10638326285380562],
#    [u'business', u"Steel firm 'to cut' 45,000 jobs", 0.0682415462388655],
#    [u'business', u'FAO warns on impact of subsidies', 0.0851522067680003],
#    [u'politics', u'UK set to cut back on embassies', 0.06897198807891029]]],
#  [u'business',
#   u'ID theft surge hits US consumers',
#   [[u'tech', u'Microsoft seeking spyware trojan', 0.08099814587762086],
#    [u'tech', u'California sets fines for spyware', 0.08079888956551129],
#    [u'tech', u'Microsoft seeking spyware trojan', 0.08099814587762086],
#    [u'tech', u"Movie body targets children's PCs", 0.08391532833483704],
#    [u'tech', u'Solutions to net security fears', 0.08219178570558851]]],
#  [u'business',
#   u'India calls for fair trade rules',
#   [[u'business', u'Dollar gains on Greenspan speech', 0.10657001160646253],
#    [u'business', u'US economy shows solid GDP growth', 0.12511108800574278],
#    [u'business', u'FAO warns on impact of subsidies', 0.11064223913747333],
#    [u'business', u"IMF 'cuts' German growth estimate", 0.10192203635169891],
#    [u'tech', u"Global digital divide 'narrowing'", 0.09841831436186584]]],
#  [u'business',
#   u'Italy to get economic action plan',
#   [[u'business', u'EU aiming to fuel development aid', 0.09654578271386849],
#    [u'business', u'EU ministers to mull jet fuel tax', 0.09833971536674257],
#    [u'business', u'Fed chief warning on US deficit', 0.09500138955946077],
#    [u'business', u"SA unveils 'more for all' budget", 0.11463115527329643],
#    [u'politics', u'Leaders meet over Turkish EU bid', 0.10333061411968894]]],
#  [u'business',
#   u"High fuel prices hit BA's profits",
#   [[u'business', u'Weak dollar hits Reuters', 0.11266918658444877],
#    [u'business', u'Ad sales boost Time Warner profit', 0.1387348307412656],
#    [u'business', u'Deutsche Telekom sees mobile gain', 0.1483199365077603],
#    [u'business', u"Ad firm WPP's profits surge 15%", 0.10231911129003936],
#    [u'business', u'Ryanair in $4bn Boeing plane deal', 0.1744361787331799]]],
#  [u'business',
#   u'Russia gets investment blessing',
#   [[u'business', u'Yukos unit buyer faces loan claim', 0.11657800664375875],
#    [u'business', u'Yukos accused of lying to court', 0.13028413623296095],
#    [u'business', u'China had role in Yukos split-up', 0.1276181138198169],
#    [u'business', u'Yukos loses US bankruptcy battle', 0.11715638021806925],
#    [u'business', u"India's rupee hits five-year high", 0.10469855719365867]]],
#  [u'business',
#   u"IMF 'cuts' German growth estimate",
#   [[u'business', u"Soaring oil 'hits world economy'", 0.1885405513233295],
#    [u'business', u'Industrial output falls in Japan', 0.12154247628543435],
#    [u'business', u'German business confidence slides', 0.13591641379143013],
#    [u'business', u'Japan economy slides to recession', 0.11934078596926599],
#    [u'business', u'German growth goes into reverse', 0.1438629731146191]]],
#  [u'business',
#   u'Ad sales boost Time Warner profit',
#   [[u'business', u'Weak dollar hits Reuters', 0.10517867006769777],
#    [u'business', u'Ask Jeeves tips online ad revival', 0.18408774286561136],
#    [u'business', u"High fuel prices hit BA's profits", 0.1387348307412656],
#    [u'business', u'Deutsche Telekom sees mobile gain', 0.11475140987581825],
#    [u'business', u"Ad firm WPP's profits surge 15%", 0.12308225995341043]]],
#  [u'business',
#   u'German growth goes into reverse',
#   [[u'business', u'German business confidence slides', 0.27487068080053956],
#    [u'business', u"IMF 'cuts' German growth estimate", 0.1438629731146191],
#    [u'business', u'Sluggish economy hits German jobs', 0.1375441558643331],
#    [u'business', u'S Korean consumers spending again', 0.11364077407745757],
#    [u'business', u'Mixed signals from French economy', 0.12998688936324576]]],
#  [u'business',
#   u"Manufacturing recovery 'slowing'",
#   [[u'business', u'Jobs growth still slow in the US', 0.10476256709780195],
#    [u'business', u'German business confidence slides', 0.13338084878021572],
#    [u'business', u'Further rise in UK jobless total', 0.13087389237978456],
#    [u'business', u'Japan economy slides to recession', 0.10540283496833892],
#    [u'business', u'German growth goes into reverse', 0.09654861894705223]]],
#  [u'business',
#   u'Fiat mulls Ferrari market listing',
#   [[u'business', u'Peugeot deal boosts Mitsubishi', 0.09867769488566125],
#    [u'business', u"Chinese wine tempts Italy's Illva", 0.09517564139481004],
#    [u'business', u'Hyundai to build new India plant', 0.07513932891138626],
#    [u'business', u'Deadline nears for Fiat-GM deal', 0.19684955603411963],
#    [u'business', u'Ad sales boost Time Warner profit', 0.07702782246158947]]],
#  [u'business',
#   u"Rank 'set to sell off film unit'",
#   [[u'business', u"High fuel prices hit BA's profits", 0.0711373357215163],
#    [u'business', u'Fiat mulls Ferrari market listing', 0.05839873706730359],
#    [u'business', u"Wembley firm won't make a profit", 0.06470222805586866],
#    [u'business', u"Ad firm WPP's profits surge 15%", 0.07512674745594333],
#    [u'business', u'Ryanair in $4bn Boeing plane deal', 0.062212582207943706]]],
#  [u'business',
#   u'Sluggish economy hits German jobs',
#   [[u'business', u'US economy shows solid GDP growth', 0.1098089815027932],
#    [u'business', u'German business confidence slides', 0.12401142681603576],
#    [u'business', u'Further rise in UK jobless total', 0.11106339470356753],
#    [u'business', u"IMF 'cuts' German growth estimate", 0.11276013691567624],
#    [u'business', u'German growth goes into reverse', 0.1375441558643331]]],
#  [u'business',
#   u'Deutsche Telekom sees mobile gain',
#   [[u'business', u'Weak dollar hits Reuters', 0.08518134488926198],
#    [u'business', u'Parmalat boasts doubled profits', 0.11046748057841586],
#    [u'business', u"High fuel prices hit BA's profits", 0.1483199365077603],
#    [u'business', u'Ad sales boost Time Warner profit', 0.11475140987581825],
#    [u'business', u'Bad weather hits Nestle sales', 0.10674007091961088]]],
#  [u'business',
#   u'S Korean consumers spending again',
#   [[u'business', u'US economy shows solid GDP growth', 0.11475451536240072],
#    [u'business', u'Home loan approvals rising again', 0.11271238529824613],
#    [u'business', u'German business confidence slides', 0.13301517523191514],
#    [u'business', u'German growth goes into reverse', 0.11364077407745757],
#    [u'business', u'China keeps tight rein on credit', 0.10342927125539692]]],
#  [u'business',
#   u'Irish markets reach all-time high',
#   [[u'business', u'India widens access to telecoms', 0.09784598492637535],
#    [u'business', u'Jobs growth still slow in the US', 0.09493622781795477],
#    [u'business', u'Industrial output falls in Japan', 0.09205376028987322],
#    [u'business', u'German business confidence slides', 0.0955813001297316],
#    [u'business', u'Further rise in UK jobless total', 0.0900748797822789]]],
#  [u'business',
#   u"Profits slide at India's Dr Reddy",
#   [[u'business', u'Hyundai to build new India plant', 0.07110052170235644],
#    [u'business', u'Cars pull down US retail figures', 0.06490377186013238],
#    [u'business', u"High fuel prices hit BA's profits", 0.06834201541412457],
#    [u'business', u"Ad firm WPP's profits surge 15%", 0.06155708054905646],
#    [u'business', u'Bad weather hits Nestle sales', 0.0850528538771667]]],
#  [u'business',
#   u'Yukos loses US bankruptcy battle',
#   [[u'business', u'Yukos unit buyer faces loan claim', 0.22488672667476062],
#    [u'business', u'Parmalat boasts doubled profits', 0.0915137220153347],
#    [u'business', u'Yukos accused of lying to court', 0.3893673997588854],
#    [u'business', u'China had role in Yukos split-up', 0.23967535348059651],
#    [u'business', u'Russia gets investment blessing', 0.11715638021806925]]],
#  [u'business',
#   u"'Strong dollar' call halts slide",
#   [[u'business', u'Dollar gains on Greenspan speech', 0.14256342171497818],
#    [u'business', u'Fed chief warning on US deficit', 0.1284163646677451],
#    [u'business', u'US trade gap hits record in 2004', 0.13902959149045707],
#    [u'business', u'Europe blames US over weak dollar', 0.24833406857292661],
#    [u'business', u'Japan economy slides to recession', 0.12245379512270747]]],
#  [u'business',
#   u"Wembley firm won't make a profit",
#   [[u'business', u'Weak dollar hits Reuters', 0.09319762402414768],
#    [u'business', u'Parmalat boasts doubled profits', 0.08322394803612027],
#    [u'business', u'Ask Jeeves tips online ad revival', 0.085992141604402],
#    [u'business', u"High fuel prices hit BA's profits", 0.07720699322522787],
#    [u'business', u'Umbro profits lifted by Euro 2004', 0.07895575412581413]]],
#  [u'business',
#   u"Ad firm WPP's profits surge 15%",
#   [[u'business', u'Weak dollar hits Reuters', 0.08628371244322129],
#    [u'business', u"High fuel prices hit BA's profits", 0.10231911129003936],
#    [u'business', u'Ad sales boost Time Warner profit', 0.12308225995341043],
#    [u'business', u'Umbro profits lifted by Euro 2004', 0.08177313518822103],
#    [u'business', u'Bad weather hits Nestle sales', 0.07529655334339337]]],
#  [u'business',
#   u'BMW cash to fuel Mini production',
#   [[u'business', u'BMW drives record sales in Asia', 0.1726958762493557],
#    [u'business', u'Hyundai to build new India plant', 0.11178532915288145],
#    [u'business', u'BMW to recall faulty diesel cars', 0.13492598461977925],
#    [u'business', u"Rover deal 'may cost 2,000 jobs'", 0.18770775445884436],
#    [u'tech', u'Apple iPod family expands market', 0.08945102203892699]]],
#  [u'business',
#   u"India's rupee hits five-year high",
#   [[u'business', u'India widens access to telecoms', 0.06731529455560832],
#    [u'business', u'Dollar gains on Greenspan speech', 0.07701674861066746],
#    [u'business', u'Hyundai to build new India plant', 0.09444392000842919],
#    [u'business', u'India calls for fair trade rules', 0.06823747590464638],
#    [u'business', u'Russia gets investment blessing', 0.10469855719365867]]],
#  [u'business',
#   u'Mixed signals from French economy',
#   [[u'business', u'US economy shows solid GDP growth', 0.13510492678317473],
#    [u'business', u"Economy 'stronger than forecast'", 0.13628421096389134],
#    [u'business', u'Industrial output falls in Japan', 0.13458728384460206],
#    [u'business', u'German business confidence slides', 0.1253101503936943],
#    [u'business', u'German growth goes into reverse', 0.12998688936324576]]],
#  [u'business',
#   u'India seeks to boost construction',
#   [[u'business', u'India widens access to telecoms', 0.10680831434887228],
#    [u'business', u'Hyundai to build new India plant', 0.06641954372074761],
#    [u'business', u"Steel firm 'to cut' 45,000 jobs", 0.07717913167584858],
#    [u'business', u'India calls for fair trade rules', 0.05707969619750387],
#    [u'business', u"Wembley firm won't make a profit", 0.05789275257595186]]],
#  [u'business',
#   u'Saudi ministry to employ women',
#   [[u'politics', u"Hewitt decries 'career sexism'", 0.07162111303919359],
#    [u'politics', u"England children's tsar appointed", 0.05485860133271667],
#    [u'politics', u'Concerns at school diploma plan', 0.04194050294252953],
#    [u'politics', u'MPs quiz aides over royal income', 0.05321127956821637],
#    [u'politics', u'Brown hits back in Blair rift row', 0.04811853227603576]]],
#  [u'business',
#   u"Turkey-Iran mobile deal 'at risk'",
#   [[u'business', u'India widens access to telecoms', 0.061154034971972956],
#    [u'business', u'Iranian MPs threaten mobile deal', 0.39261745793252933],
#    [u'business', u'Argentina closes $102.6bn debt swap', 0.059640872802006945],
#    [u'business', u'Irish markets reach all-time high', 0.059264952304970135],
#    [u'politics', u'Blair hails Turkey-EU talks deal', 0.06887472627355198]]],
#  [u'business',
#   u'China keeps tight rein on credit',
#   [[u'business', u'Dollar gains on Greenspan speech', 0.09726481596494262],
#    [u'business', u'Industrial output falls in Japan', 0.12697163711525342],
#    [u'business', u'German business confidence slides', 0.11211689007272765],
#    [u'business', u'German growth goes into reverse', 0.10471697396099419],
#    [u'business', u'S Korean consumers spending again', 0.10342927125539692]]],
#  [u'business',
#   u'Air passengers win new EU rights',
#   [[u'business', u'Lufthansa may sue over Bush visit', 0.1497034155198839],
#    [u'business', u'Ryanair in $4bn Boeing plane deal', 0.1022516060121065],
#    [u'business', u'Boeing unveils new 777 aircraft', 0.09667497763042376],
#    [u'tech', u"'No re-draft' for EU patent law", 0.08414676214895539],
#    [u'politics', u'Protesters plan airport challenge', 0.08613242391925569]]],
#  [u'business',
#   u'Ryanair in $4bn Boeing plane deal',
#   [[u'business', u'Lufthansa may sue over Bush visit', 0.09299265879877579],
#    [u'business', u"High fuel prices hit BA's profits", 0.1744361787331799],
#    [u'business', u'Ad sales boost Time Warner profit', 0.08369723225583066],
#    [u'business', u'Air passengers win new EU rights', 0.1022516060121065],
#    [u'business', u'Boeing unveils new 777 aircraft', 0.23071955410931233]]],
#  [u'business',
#   u'US crude prices surge above $53',
#   [[u'business', u'Industrial output falls in Japan', 0.08537352687169905],
#    [u'business', u'China had role in Yukos split-up', 0.06956397884016041],
#    [u'business', u'Strong demand triggers oil rally', 0.1778391145915154],
#    [u'business', u'Irish markets reach all-time high', 0.06735062374042156],
#    [u'business', u'Bad weather hits Nestle sales', 0.06866017293430716]]],
#  [u'business',
#   u"SA unveils 'more for all' budget",
#   [[u'business', u'Fed chief warning on US deficit', 0.09621631730924418],
#    [u'business', u'US economy shows solid GDP growth', 0.11586546905639175],
#    [u'business', u'German business confidence slides', 0.1001111939672408],
#    [u'business', u'Italy to get economic action plan', 0.11463115527329643],
#    [u'politics', u'Brown names 16 March for Budget', 0.12362905393658835]]],
#  [u'business',
#   u'Umbro profits lifted by Euro 2004',
#   [[u'business', u'Parmalat to return to stockmarket', 0.07923951329070804],
#    [u'business', u"High fuel prices hit BA's profits", 0.10202601747018657],
#    [u'business', u'Ad sales boost Time Warner profit', 0.07922467595423174],
#    [u'business', u"Wembley firm won't make a profit", 0.07895575412581413],
#    [u'business', u"Ad firm WPP's profits surge 15%", 0.08177313518822103]]],
#  [u'business',
#   u'Bad weather hits Nestle sales',
#   [[u'business', u"Soaring oil 'hits world economy'", 0.09072551524753295],
#    [u'business', u'BMW drives record sales in Asia', 0.08775679919769763],
#    [u'business', u"High fuel prices hit BA's profits", 0.08976994693633912],
#    [u'business', u'Ad sales boost Time Warner profit', 0.09522861328292034],
#    [u'business', u'Deutsche Telekom sees mobile gain', 0.10674007091961088]]],
#  [u'business',
#   u'Boeing unveils new 777 aircraft',
#   [[u'business', u'Parmalat boasts doubled profits', 0.06421676221381951],
#    [u'business', u'Lufthansa may sue over Bush visit', 0.10392401801943026],
#    [u'business', u"High fuel prices hit BA's profits", 0.09748587431023141],
#    [u'business', u'Air passengers win new EU rights', 0.09667497763042376],
#    [u'business', u'Ryanair in $4bn Boeing plane deal', 0.23071955410931233]]],
#  [u'business',
#   u'Court rejects $280bn tobacco case',
#   [[u'business', u'Yukos accused of lying to court', 0.06774994447733775],
#    [u'politics', u'Lords wrong on detainees - Straw', 0.05850275927842174],
#    [u'politics', u'Scots smoking ban details set out', 0.07529765213836061],
#    [u'sport', u'Trial date is set for Balco case', 0.05869546532000545],
#    [u'entertainment',
#     u'No ads for Passion Oscar campaign',
#     0.059589107825756174]]],
#  [u'business',
#   u'Takeover rumour lifts Exel shares',
#   [[u'business', u'Japanese banking battle at an end', 0.05741099555253994],
#    [u'business', u'Circuit City gets takeover offer', 0.10230935696221909],
#    [u'business', u'Deadline nears for Fiat-GM deal', 0.06050103323074072],
#    [u'business', u'Pernod takeover talk lifts Domecq', 0.09491434495872718],
#    [u'business', u'Fiat mulls Ferrari market listing', 0.05391381065799224]]],
#  [u'tech',
#   u'Microsoft seeking spyware trojan',
#   [[u'tech', u'Microsoft releases bumper patches', 0.20704905547814742],
#    [u'tech', u'Microsoft makes anti-piracy move', 0.138570746871574],
#    [u'tech', u'Security scares spark browser fix', 0.14473694162203743],
#    [u'tech', u'Microsoft releases patches', 0.20919681590704925],
#    [u'tech', u'Virus poses as Christmas e-mail', 0.16948727877043154]]],
#  [u'tech',
#   u'Reboot ordered for EU patent law',
#   [[u'business', u'EU ministers to mull jet fuel tax', 0.08099224847777223],
#    [u'tech', u'EU software patent law faces axe', 0.23066119454015682],
#    [u'tech', u'New delay hits EU software laws', 0.47085438631472],
#    [u'tech', u'Open source leaders slam patents', 0.09727238064701416],
#    [u'tech', u"'No re-draft' for EU patent law", 0.4813932583709394]]]]

# %%
#4: Search Documents

# %%
#this function take query and let it goes through the same process as every document
#to create a vector that represent the query
def calculateNormVector(query):
    tokens = tokenizeWithoutStopWords(query)
    Tft_dict = calculate_TFt(tokens)
    vector = vectorize(Tft_dict)
    return normalize(vector)

# %%
#this function get query and return the 10 documents most match to the query
def getTop10MatchDocuments(query):
    norm_vector = calculateNormVector(query)
    files_with_score_rdd = files_with_norm_vectors_rdd.map(lambda row: (calculateCos(norm_vector,row[2]),[row[0],row[1]]))
    top10Documents = files_with_score_rdd.sortByKey( ascending=False).top(10)
    return top10Documents

# %%
#here we demonstrate 5 query's results

# %%
result = getTop10MatchDocuments('Iranian MPs threaten mobile deal')
result
# Out:
# [(0.1824159334714062, [u'business', u'Iranian MPs threaten mobile deal']),
#  (0.09581945879305956, [u'business', u"Turkey-Iran mobile deal 'at risk'"]),
#  (0.09031794351730849, [u'tech', u'Iran jails blogger for 14 years']),
#  (0.08253258656578713, [u'politics', u'Strike threat over pension plans']),
#  (0.06932724186100198, [u'tech', u'Global blogger action day called']),
#  (0.06041681644578025, [u'business', u'German growth goes into reverse']),
#  (0.050730112629216756,
#   [u'entertainment', u"Dutch watch Van Gogh's last film"]),
#  (0.04958782009732701, [u'politics', u"EU China arms ban 'to be lifted'"]),
#  (0.04746678500041163, [u'politics', u"Visa decision 'every 11 minutes'"]),
#  (0.04740701986473111, [u'politics', u"Tories 'would cut number of MPs'"])]

# %%
result = getTop10MatchDocuments('apple release new phone')
result
# Out:
# [(0.13122358473408607, [u'tech', u'Apple iPod family expands market']),
#  (0.1221101881003855, [u'tech', u'Creator of first Apple Mac dies']),
#  (0.10688885716178981, [u'tech', u'Looks and music to drive mobiles']),
#  (0.09702065243481324, [u'tech', u'Apple attacked over sources row']),
#  (0.07712721790064272, [u'sport', u'Chepkemei joins Edinburgh line-up']),
#  (0.07558380554858865, [u'tech', u"Apple laptop is 'greatest gadget'"]),
#  (0.07367087468828566, [u'tech', u'The future in your pocket']),
#  (0.07348096335376353, [u'tech', u"Mobiles 'not media players yet'"]),
#  (0.06321309247495756, [u'tech', u'Moving mobile improves golf swing']),
#  (0.05637205584105738, [u'tech', u"'Friends fear' with lost mobiles"])]

# %%
result = getTop10MatchDocuments('us economy')
result
# Out:
# [(0.13052158321173868, [u'business', u'US economy shows solid GDP growth']),
#  (0.11089557786294216, [u'business', u"IMF 'cuts' German growth estimate"]),
#  (0.10315688342552369, [u'business', u'Mixed signals from French economy']),
#  (0.09775902160791343, [u'business', u'German growth goes into reverse']),
#  (0.09614733272759357, [u'business', u'Japan economy slides to recession']),
#  (0.09189225378449573, [u'business', u'Japan narrowly escapes recession']),
#  (0.09052721366737784, [u'business', u'Palestinian economy in decline']),
#  (0.08969383167401589, [u'business', u'Industrial output falls in Japan']),
#  (0.08769767679747476, [u'business', u'Fed chief warning on US deficit']),
#  (0.0867721655632652, [u'politics', u"Job cuts 'false economy'  - TUC"])]

# %%
result = getTop10MatchDocuments('victoria secrets')
result
# Out:
# [(0.09364395452672605,
#   [u'entertainment', u'Bennett play takes theatre prizes']),
#  (0.07595090889996216,
#   [u'entertainment', u"Artists' secret postcards on sale"]),
#  (0.07253421468031208, [u'entertainment', u'West End to honour finest shows']),
#  (0.07169090743957085, [u'entertainment', u'Da Vinci film to star Tom Hanks']),
#  (0.052704826817009595, [u'politics', u"Nuclear strike 'key terror risk'"]),
#  (0.049885607231128094, [u'politics', u'Russian ex-spy on hunger strike']),
#  (0.0, [u'tech', u'Yahoo celebrates a decade online']),
#  (0.0, [u'tech', u"Xbox power cable 'fire fear'"]),
#  (0.0, [u'tech', u'Xbox 2 may be unveiled in summer']),
#  (0.0, [u'tech', u'Wi-fi web reaches farmers in Peru'])]

# %%
result = getTop10MatchDocuments('GOOGLE TECH')
result
# Out:
# [(0.10679364007277317, [u'tech', u'Google launches TV search service']),
#  (0.09663454844206254, [u'tech', u'Security scares spark browser fix']),
#  (0.09104057398052501, [u'business', u'Ask Jeeves tips online ad revival']),
#  (0.09089566403080483, [u'tech', u"Google's toolbar sparks concern"]),
#  (0.07708767737670094, [u'tech', u"'No re-draft' for EU patent law"]),
#  (0.06630451409394633, [u'tech', u'Microsoft launches its own search']),
#  (0.06339658238293512, [u'tech', u'Web helps collect aid donations']),
#  (0.06306294406686896, [u'tech', u'Rich pickings for hi-tech thieves']),
#  (0.06229664510781492, [u'tech', u'EU software patent law faces axe']),
#  (0.062070249378083975, [u'business', u'Ad sales boost Time Warner profit'])]

# %%
#Kmeans

# %%
categories = files_with_vectors_rdd.map(lambda row: row[0]).distinct().collect()

# %%
def getRandomCenters():
    centers = {}
    group = 1
    for category in categories:
        row = files_with_norm_vectors_rdd.filter(lambda r: r[0] == category).first()
        centers[group] = row[2]
        group = group +1
    return centers

# %%
def calculateDistance(v1,v2):
    sub_V = [0]*len(v1)
    for i in range(0,len(v1)):
        sub_V[i] = (v1[i]-v2[i]) * (v1[i]-v2[i])
    return math.sqrt(sum(sub_V))

# %%
def checkIfAlgorithmFinish(current_centers,new_centers):
    groups = current_centers.keys() 
    for group in groups:
        distance = calculateDistance(current_centers[group],new_centers[group])
        if(distance > 0.0000000001):
            return False
    return True

# %%
def findNearestCenters(row,current_centers):
    groups = current_centers.keys()
    minDistance = -1
    minGroup = 0
    for group in groups:
        distance = calculateDistance(row[2],current_centers[group])
        if(distance < minDistance or minDistance == -1):
            minDistance = distance
            minGroup = group
    return(minGroup, row)

# %%
def calculateCenter(rows):
    center = [0]*vector_size
    if(len(rows) > 0):
        for r in rows:
            v=r[2]
            for i in range(0,vector_size):
                center[i] = center[i] + v[i]
        for i in range(0,vector_size):
            center[i] = center[i] / len(rows)
    return center

# %%
def calculateNewCenters(cluster_vectors):
    centers = cluster_vectors.map(lambda (k,v): (k,calculateCenter(list(v))))
    return dict(centers.collect())

# %%
def kmeans():
    current_centers = getRandomCenters()
    finish = False
    i = 0
    while finish== False:
        cluster_vectors = files_with_norm_vectors_rdd.map(lambda row:findNearestCenters(row,current_centers)).groupByKey()
        new_centers = calculateNewCenters(cluster_vectors)
        finish = checkIfAlgorithmFinish(current_centers,new_centers)
        current_centers = new_centers
        i = i+1
    return [cluster_vectors,current_centers]

# %%
cluster_vectors_and_centers = kmeans()
cluster_vectors = cluster_vectors_and_centers[0]
centers = cluster_vectors_and_centers[1]

# %%
#here we can see the result of the kmeans algorithm
#we can see that every cluster have a strong connection to one category label 
#although we have some noise in the data

# %%
cluster_vectors.map(lambda(k,v): (k,map(lambda x: x[:-1],list(v)))).take(5)
# Out:
# [(2,
#   [[u'business', u'Yukos unit buyer faces loan claim'],
#    [u'business', u'Weak dollar hits Reuters'],
#    [u'business', u'BMW drives record sales in Asia'],
#    [u'business', u'Metlife buys up Citigroup insurer'],
#    [u'business', u'Parmalat boasts doubled profits'],
#    [u'business', u'Japanese banking battle at an end'],
#    [u'business', u'Ask Jeeves tips online ad revival'],
#    [u'business', u'EU aiming to fuel development aid'],
#    [u'business', u'Japanese mogul arrested for fraud'],
#    [u'business', u'Burren awarded Egyptian contracts'],
#    [u'business', u'Telegraph newspapers axe 90 jobs'],
#    [u'business', u'Lufthansa may sue over Bush visit'],
#    [u'business', u'Yukos accused of lying to court'],
#    [u'business', u'Peugeot deal boosts Mitsubishi'],
#    [u'business', u"Chinese wine tempts Italy's Illva"],
#    [u'business', u'Hyundai to build new India plant'],
#    [u'business', u'Electrolux to export Europe jobs'],
#    [u'business', u'Worldcom ex-boss launches defence'],
#    [u'business', u'Circuit City gets takeover offer'],
#    [u'business', u'UK Coal plunges into deeper loss'],
#    [u'business', u'Argentina, Venezuela in oil deal'],
#    [u'business', u"Worldcom boss 'left books alone'"],
#    [u'business', u'Safety alert as GM recalls cars'],
#    [u'business', u'Deadline nears for Fiat-GM deal'],
#    [u'business', u"Steel firm 'to cut' 45,000 jobs"],
#    [u'business', u'Home loan approvals rising again'],
#    [u'business', u'UK firm faces Venezuelan land row'],
#    [u'business', u'Cars pull down US retail figures'],
#    [u'business', u'Parmalat to return to stockmarket'],
#    [u'business', u'Pernod takeover talk lifts Domecq'],
#    [u'business', u'China had role in Yukos split-up'],
#    [u'business', u'BMW to recall faulty diesel cars'],
#    [u'business', u'Argentina closes $102.6bn debt swap'],
#    [u'business', u'Indonesians face fuel price rise'],
#    [u'business', u"Rover deal 'may cost 2,000 jobs'"],
#    [u'business', u'Insurance bosses plead guilty'],
#    [u'business', u'Mexican in US send $16bn home'],
#    [u'business', u'Strong demand triggers oil rally'],
#    [u'business', u'Italy to get economic action plan'],
#    [u'business', u"High fuel prices hit BA's profits"],
#    [u'business', u'Russia gets investment blessing'],
#    [u'business', u"IMF 'cuts' German growth estimate"],
#    [u'business', u'Ad sales boost Time Warner profit'],
#    [u'business', u'Fiat mulls Ferrari market listing'],
#    [u'business', u"Rank 'set to sell off film unit'"],
#    [u'business', u'Deutsche Telekom sees mobile gain'],
#    [u'business', u'S Korean consumers spending again'],
#    [u'business', u'Irish markets reach all-time high'],
#    [u'business', u"Profits slide at India's Dr Reddy"],
#    [u'business', u'Yukos loses US bankruptcy battle'],
#    [u'business', u"Wembley firm won't make a profit"],
#    [u'business', u"Ad firm WPP's profits surge 15%"],
#    [u'business', u'BMW cash to fuel Mini production'],
#    [u'business', u"India's rupee hits five-year high"],
#    [u'business', u'China keeps tight rein on credit'],
#    [u'business', u'Air passengers win new EU rights'],
#    [u'business', u'Ryanair in $4bn Boeing plane deal'],
#    [u'business', u'US crude prices surge above $53'],
#    [u'business', u'Umbro profits lifted by Euro 2004'],
#    [u'business', u'Bad weather hits Nestle sales'],
#    [u'business', u'Court rejects $280bn tobacco case'],
#    [u'business', u'Takeover rumour lifts Exel shares'],
#    [u'tech', u'Reboot ordered for EU patent law'],
#    [u'tech', u'New delay hits EU software laws'],
#    [u'tech', u'Apple attacked over sources row'],
#    [u'tech', u'Sun offers processing by the hour'],
#    [u'tech', u'Sony PSP console hits US in March'],
#    [u'tech', u'Iran jails blogger for 14 years'],
#    [u'politics', u'Russian ex-spy on hunger strike'],
#    [u'politics', u"Guantanamo man 'suing government'"],
#    [u'politics', u"EU China arms ban 'to be lifted'"],
#    [u'politics', u"Anglers 'could face prosecution'"],
#    [u'politics', u"'Errors' doomed first Dome sale"],
#    [u'politics', u'MSPs hear renewed climate warning'],
#    [u'sport', u"Jones medals 'must go if guilty'"],
#    [u'sport', u'Jones doping probe begins'],
#    [u'sport', u'Collins appeals against drugs ban'],
#    [u'sport', u'Balco case trial date pushed back'],
#    [u'sport', u'Collins banned in landmark case'],
#    [u'sport', u'Trial date is set for Balco case'],
#    [u'entertainment', u"Artists' secret postcards on sale"]]),
#  (4,
#   [[u'sport', u'Greene sets sights on world title'],
#    [u'sport', u'2004: An Irish Athletics Year'],
#    [u'sport', u'Gebrselassie in London triple bid'],
#    [u'sport', u'African double in Edinburgh'],
#    [u'sport', u'Kluft impressed by Sotherton form'],
#    [u'sport', u'Call for Kenteris to be cleared'],
#    [u'sport', u'London hope over Chepkemei'],
#    [u'sport', u'Bekele sets sights on world mark'],
#    [u'sport', u'Radcliffe yet to answer GB call'],
#    [u'sport', u'Radcliffe will compete in London'],
#    [u'sport', u'Johnson accuses British sprinters'],
#    [u'sport', u'Gardener wins double in Glasgow'],
#    [u'sport', u'McIlroy aiming for Madrid title'],
#    [u'sport', u'Collins calls for Chambers return'],
#    [u'sport', u"O'Sullivan could run in Worlds"],
#    [u'sport', u'McIlroy continues winning streak'],
#    [u'sport', u"O'Sullivan commits to Dublin race"],
#    [u'sport', u'Johnson too strong for GB runners'],
#    [u'sport', u"Kenya lift Chepkemei's suspension"],
#    [u'sport', u'Gatlin and Hayes win Owen awards'],
#    [u'sport', u'Lewis-Francis turns to Christie'],
#    [u'sport', u'Chepkemei joins Edinburgh line-up'],
#    [u'sport', u'Thanou bullish over drugs hearing'],
#    [u'sport', u'Gardener battles to narrow win'],
#    [u'sport', u'European medal chances improve'],
#    [u'sport', u'Record fails to lift lacklustre meet'],
#    [u'sport', u'Radcliffe enjoys winning comeback'],
#    [u'sport', u"Greek sprinters 'won't run again'"],
#    [u'sport', u'What now for Kelly Holmes?'],
#    [u'sport', u'GB quartet get cross country call'],
#    [u'sport', u'Edwards tips Idowu for Euro gold'],
#    [u'sport', u'Thanou desperate to make return'],
#    [u'sport', u'Butler strikes gold in Spain'],
#    [u'sport', u'Radcliffe eyes hard line on drugs'],
#    [u'sport', u'Holmes feted with further honour'],
#    [u'sport', u'Off-colour Gardener storms to win'],
#    [u'sport', u'Lewis-Francis eyeing world gold'],
#    [u'sport', u'Tulu to appear at Caledonian run'],
#    [u'sport', u'Isinbayeva heads for Birmingham'],
#    [u'sport', u'Holmes urged to compete at Worlds'],
#    [u'sport', u'Greek pair set for hearing'],
#    [u'sport', u'Britain boosted by Holmes double'],
#    [u'sport', u'Dibaba breaks 5,000m world record'],
#    [u'sport', u'Yelling takes Cardiff hat-trick'],
#    [u'sport', u'Johnson edges out rival Sotherton'],
#    [u'sport', u'IAAF will contest Greek decision'],
#    [u'sport', u'Greek sprinters suspended by IAAF'],
#    [u'sport', u'Tomlinson stays focused on Europe'],
#    [u'sport', u'Costin aims for comeback in 2006'],
#    [u'sport', u'Edwards tips Idowu for Euro gold'],
#    [u'sport', u'Isinbayeva claims new world best'],
#    [u'sport', u'Athens memories soar above lows'],
#    [u'sport', u'McIlroy wins 800m indoor title'],
#    [u'sport', u'White admits to Balco drugs link'],
#    [u'sport', u'Holmes starts 2005 with GB events'],
#    [u'sport', u'Campbell to extend sprint career'],
#    [u'sport', u'Relay squad thrilled with honours'],
#    [u'sport', u'Wada will appeal against ruling'],
#    [u'sport', u"Hansen 'delays return until 2006'"],
#    [u'sport', u'Holmes starts 2005 with GB events'],
#    [u'sport', u'IAAF launches fight against drugs'],
#    [u'sport', u'Claxton hunting first major medal'],
#    [u'sport', u'Johnson uncertain about Euro bid'],
#    [u'sport', u'Disappointed Scott in solid start'],
#    [u'sport', u'IAAF to rule on Greek sprint pair'],
#    [u'sport', u'Chepkemei hit by big ban'],
#    [u'sport', u'Holmes secures comeback victory'],
#    [u'sport', u'Radcliffe proves doubters wrong'],
#    [u'sport', u'Running around the Olympics'],
#    [u'sport', u'Sprinter Walker quits athletics'],
#    [u'sport', u'El Guerrouj targets cross country'],
#    [u'sport', u"Brizzel to run AAA's in Sheffield"],
#    [u'sport', u'Gerrard plays down European hopes'],
#    [u'sport', u'Merritt close to indoor 400m mark'],
#    [u'sport', u'Greek pair attend drugs hearing'],
#    [u'sport', u'GB select Holmes for double bid'],
#    [u'sport', u'Collins named UK Athletics chief'],
#    [u'sport', u'Pavey focuses on indoor success'],
#    [u'sport', u'Verdict delay for Greek sprinters'],
#    [u'sport', u'UK Athletics agrees new kit deal'],
#    [u'sport', u'Kenteris denies faking road crash'],
#    [u'sport', u'Holmes is hit by hamstring injury'],
#    [u'sport', u'Radcliffe tackles marathon tasks'],
#    [u'sport', u"IAAF awaits Greek pair's response"],
#    [u'sport', u'Holmes back on form in Birmingham'],
#    [u'sport', u'Collins to compete in Birmingham'],
#    [u'sport', u'Greek duo cleared in doping case']]),
#  (1,
#   [[u'business', u'Iranian MPs threaten mobile deal'],
#    [u'business', u"Ethiopia's crop production up 24%"],
#    [u'business', u'ID theft surge hits US consumers'],
#    [u'business', u"Turkey-Iran mobile deal 'at risk'"],
#    [u'tech', u'Microsoft seeking spyware trojan'],
#    [u'tech', u'Microsoft launches its own search'],
#    [u'tech', u'Google launches TV search service'],
#    [u'tech', u'UK net users leading TV downloads'],
#    [u'tech', u'US peer-to-peer pirates convicted'],
#    [u'tech', u'California sets fines for spyware'],
#    [u'tech', u'EU software patent law faces axe'],
#    [u'tech', u"Norway upholds 'Napster' ruling"],
#    [u'tech', u'Microsoft releases bumper patches'],
#    [u'tech', u'Microsoft makes anti-piracy move'],
#    [u'tech', u"Security warning over 'FBI virus'"],
#    [u'tech', u'Microsoft seeking spyware trojan'],
#    [u'tech', u'Moving mobile improves golf swing'],
#    [u'tech', u'BT boosts its broadband packages'],
#    [u'tech', u'Telewest to challenge Sky Plus'],
#    [u'tech', u'Hotspot users gain free net calls'],
#    [u'tech', u'Warnings about junk mail deluge'],
#    [u'tech', u'Security scares spark browser fix'],
#    [u'tech', u'Latest Opera browser gets vocal'],
#    [u'tech', u'Blog reading explodes in America'],
#    [u'tech', u'Warning over tsunami aid website'],
#    [u'tech', u'Tough rules for ringtone sellers'],
#    [u'tech', u'Open source leaders slam patents'],
#    [u'tech', u"'No re-draft' for EU patent law"],
#    [u'tech', u'Rich pickings for hi-tech thieves'],
#    [u'tech', u'Concern over RFID tags'],
#    [u'tech', u'Savvy searchers fail to spot ads'],
#    [u'tech', u'IBM puts cash behind Linux push'],
#    [u'tech', u'UK gets official virus alert site'],
#    [u'tech', u'Microsoft releases patches'],
#    [u'tech', u'Nintendo handheld given Euro date'],
#    [u'tech', u'Bush website blocked outside US'],
#    [u'tech', u'Piero gives rugby perspective'],
#    [u'tech', u'Software watching while you work'],
#    [u'tech', u'Virus poses as Christmas e-mail'],
#    [u'tech', u'Xbox 2 may be unveiled in summer'],
#    [u'tech', u"Movie body targets children's PCs"],
#    [u'tech', u"'Evil twin' fear for wireless net"],
#    [u'tech', u'Warning over Windows Word files'],
#    [u'tech', u'Britons fed up with net service'],
#    [u'tech', u'Movie body hits peer-to-peer nets'],
#    [u'tech', u'Nuclear body seeks new tech'],
#    [u'tech', u'Solutions to net security fears'],
#    [u'tech', u'Web helps collect aid donations'],
#    [u'tech', u'Ask Jeeves joins web log market'],
#    [u'tech', u'Domain system scam fear'],
#    [u'tech', u'DVD copy protection strengthened'],
#    [u'tech', u"Xbox power cable 'fire fear'"],
#    [u'tech', u'Junk e-mails on relentless rise'],
#    [u'tech', u'Apple iPod family expands market'],
#    [u'tech', u"'Friends fear' with lost mobiles"],
#    [u'tech', u"Google's toolbar sparks concern"],
#    [u'tech', u"Games firms 'face tough future'"],
#    [u'politics', u"Guantanamo pair's passport ban"],
#    [u'politics', u'Watchdog probes e-mail deletions'],
#    [u'politics', u"Assembly ballot papers 'missing'"],
#    [u'politics', u"Nuclear strike 'key terror risk'"],
#    [u'sport', u'Jones files lawsuit against Conte'],
#    [u'sport', u'Duff ruled out of Barcelona clash'],
#    [u'sport', u'Jones files Conte lawsuit'],
#    [u'entertainment', u'Mumbai bombs movie postponed'],
#    [u'entertainment', u'Gallery unveils interactive tree'],
#    [u'entertainment', u'Versace art portfolio up for sale']]),
#  (3,
#   [[u'business', u"Soaring oil 'hits world economy'"],
#    [u'business', u'Palestinian economy in decline'],
#    [u'business', u'India widens access to telecoms'],
#    [u'business', u'EU ministers to mull jet fuel tax'],
#    [u'business', u'Dollar gains on Greenspan speech'],
#    [u'business', u'Jobs growth still slow in the US'],
#    [u'business', u'Fed chief warning on US deficit'],
#    [u'business', u'US economy shows solid GDP growth'],
#    [u'business', u'US gives foreign firms extra time'],
#    [u'business', u'US trade gap hits record in 2004'],
#    [u'business', u"Economy 'stronger than forecast'"],
#    [u'business', u"Call centre users 'lose patience'"],
#    [u'business', u'Europe blames US over weak dollar'],
#    [u'business', u'Industrial output falls in Japan'],
#    [u'business', u'FAO warns on impact of subsidies'],
#    [u'business', u'German business confidence slides'],
#    [u'business', u'Further rise in UK jobless total'],
#    [u'business', u'Rich grab half Colombia poor fund'],
#    [u'business', u'Japan turns to beer alternatives'],
#    [u'business', u'Japan narrowly escapes recession'],
#    [u'business', u'Japan economy slides to recession'],
#    [u'business', u'French wine gets 70m euro top-up'],
#    [u'business', u'India calls for fair trade rules'],
#    [u'business', u'German growth goes into reverse'],
#    [u'business', u"Manufacturing recovery 'slowing'"],
#    [u'business', u'Sluggish economy hits German jobs'],
#    [u'business', u"'Strong dollar' call halts slide"],
#    [u'business', u'Mixed signals from French economy'],
#    [u'business', u'India seeks to boost construction'],
#    [u'business', u'Saudi ministry to employ women'],
#    [u'business', u"SA unveils 'more for all' budget"],
#    [u'business', u'Boeing unveils new 777 aircraft'],
#    [u'tech', u'Sporting rivals go to extra time'],
#    [u'tech', u'Voters flock to blog awards site'],
#    [u'tech', u'Finding new homes for old phones'],
#    [u'tech', u'Intel unveils laser breakthrough'],
#    [u'tech', u"Camera phones are 'must-haves'"],
#    [u'tech', u'Mobile networks seek turbo boost'],
#    [u'tech', u'Yahoo celebrates a decade online'],
#    [u'tech', u'US woman sues over cartridges'],
#    [u'tech', u'China net cafe culture crackdown'],
#    [u'tech', u'Looks and music to drive mobiles'],
#    [u'tech', u'UK pioneers digital film network'],
#    [u'tech', u"T-Mobile bets on 'pocket office'"],
#    [u'tech', u'What high-definition will do to DVDs'],
#    [u'tech', u"Game firm holds 'cast' auditions"],
#    [u'tech', u"Mobiles 'not media players yet'"],
#    [u'tech', u'Half-Life 2 sweeps Bafta awards'],
#    [u'tech', u"Net regulation 'still possible'"],
#    [u'tech', u"Apple laptop is 'greatest gadget'"],
#    [u'tech', u'Smart search lets art fans browse'],
#    [u'tech', u'Digital guru floats sub-$100 PC'],
#    [u'tech', u'Blogs take on the mainstream'],
#    [u'tech', u'Kenyan school turns to handhelds'],
#    [u'tech', u'Technology gets the creative bug'],
#    [u'tech', u"Global digital divide 'narrowing'"],
#    [u'tech', u'Games enter the classroom'],
#    [u'tech', u'The future in your pocket'],
#    [u'tech', u'Wi-fi web reaches farmers in Peru'],
#    [u'tech', u'Web radio takes Spanish rap global'],
#    [u'tech', u'Digital guru floats sub-$100 PC'],
#    [u'tech', u'Mobiles rack up 20 years of use'],
#    [u'tech', u'Ink helps drive democracy in Asia'],
#    [u'tech', u"Blind student 'hears in colour'"],
#    [u'tech', u'Gadget growth fuels eco concerns'],
#    [u'tech', u'Mobile games come of age'],
#    [u'tech', u'Blogger grounded by her airline'],
#    [u'tech', u'PlayStation 3 chip to be unveiled'],
#    [u'tech', u'Lasers help bridge network gaps'],
#    [u'tech', u"China 'to overtake US net use'"],
#    [u'tech', u'Global blogger action day called'],
#    [u'tech', u'Millions buy MP3 players in US'],
#    [u'tech', u"Sony PSP tipped as a 'must-have'"],
#    [u'tech', u'Cheaper chip for mobiles'],
#    [u'tech', u"Games 'deserve a place in class'"],
#    [u'politics', u"Hewitt decries 'career sexism'"],
#    [u'politics', u"Labour targets 'hardcore truants'"],
#    [u'politics', u'Report attacks defence spending'],
#    [u'politics', u'Citizenship event for 18s touted'],
#    [u'politics', u"Campaign 'cold calls' questioned"],
#    [u'politics', u'Tsunami debt deal to be announced'],
#    [u'politics', u"Drink remark 'acts as diversion'"],
#    [u'politics', u'Minimum rate for foster parents'],
#    [u'politics', u'Hunt demo at Labour meeting'],
#    [u'politics', u'Mrs Howard gets key election role'],
#    [u'politics', u'Profile: David Miliband'],
#    [u'politics', u'Boris opposes mayor apology'],
#    [u'politics', u"Tories 'would cut number of MPs'"],
#    [u'politics', u'Blair rejects Tory terror offer'],
#    [u'politics', u"New 'yob' targets to be unveiled"],
#    [u'politics', u'Blair hails Turkey-EU talks deal'],
#    [u'politics', u"Fox attacks Blair's Tory 'lies'"],
#    [u'politics', u"Hague 'given up' his PM ambition"],
#    [u'politics', u'Howard rebuts asylum criticisms'],
#    [u'politics', u"'Hitler' row over Welsh arts cash"],
#    [u'politics', u'Profile: David Blunkett'],
#    [u'politics', u"McConnell in 'drunk' remark row"],
#    [u'politics', u'Choose hope over fear - Kennedy'],
#    [u'politics', u'Brown visits slum on Africa trip'],
#    [u'politics', u"Lib Dems 'to target stamp duty'"],
#    [u'politics', u"'Debate needed' on donations cap"],
#    [u'politics', u'Opposition grows to house arrests'],
#    [u'politics', u'Strike threat over pension plans'],
#    [u'politics', u"'More to do' on adult literacy"],
#    [u'politics', u"England children's tsar appointed"],
#    [u'politics', u'Howard unveils Tory asylum plans'],
#    [u'politics', u'Blair sets date for Africa report'],
#    [u'politics', u'Concerns at school diploma plan'],
#    [u'politics', u'Tory leader quits legal position'],
#    [u'politics', u'Asylum children to face returns'],
#    [u'politics', u'Blair and Blunkett Sheffield trip'],
#    [u'politics', u'Butler launches attack on Blair'],
#    [u'politics', u"Campbell: E-mail row 'silly fuss'"],
#    [u'politics', u'Child access laws shake-up'],
#    [u'politics', u"UK's 'useless' quangos under fire"],
#    [u'politics', u'UK set to cut back on embassies'],
#    [u'politics', u"Drive to 'save' festive holidays"],
#    [u'politics', u'Blair stresses prosperity goals'],
#    [u'politics', u'Commons hunt protest charges'],
#    [u'politics', u'Brown ally rejects Budget spree'],
#    [u'politics', u'Brown names 16 March for Budget'],
#    [u'politics', u'Tory backing for ID cards'],
#    [u'politics', u'Protesters plan airport challenge'],
#    [u'politics', u"Visa decision 'every 11 minutes'"],
#    [u'politics', u'Kennedy calls for Iraq exit plans'],
#    [u'politics', u"Tories attack burglar 'U-turns'"],
#    [u'politics', u'Cardinal criticises Iraq war cost'],
#    [u'politics', u'MPs quiz aides over royal income'],
#    [u'politics', u"Job cuts 'false economy'  - TUC"],
#    [u'politics', u"Council tax rise 'reasonable'"],
#    [u'politics', u'Lib Dems demand new inquiry'],
#    [u'politics', u"'Fido' to be taken off vote lists"],
#    [u'politics', u'Women MPs reveal sexist taunts'],
#    [u'politics', u'Labour chooses Manchester'],
#    [u'politics', u"Vouchers 'to cut winter deaths'"],
#    [u'politics', u"Ministers deny care sums 'wrong'"],
#    [u'politics', u'Labour plans maternity pay rise'],
#    [u'politics', u'No to Royal succession shake-up'],
#    [u'politics', u'Howard backs stem cell research'],
#    [u'politics', u'MPs criticise child access system'],
#    [u'politics', u"Blair backs 'pre-election budget'"],
#    [u'politics', u'Nat Insurance to rise, say Tories'],
#    [u'politics', u'Borders rail link campaign rally'],
#    [u'politics', u"Muslim police stops 'more likely'"],
#    [u'politics', u"'No more concessions' on terror"],
#    [u'politics', u'Blunkett sorry over murder plan'],
#    [u'politics', u'Brown hits back in Blair rift row'],
#    [u'politics', u"UK 'needs true immigration data'"],
#    [u'politics', u'UK plan to deport terror suspects'],
#    [u'politics', u'Muslims discuss election concerns'],
#    [u'politics', u'Leaders meet over Turkish EU bid'],
#    [u'politics', u'Clarke to press on with ID cards'],
#    [u'politics', u'Blunkett row should end - Blair'],
#    [u'politics', u"E-University 'disgraceful waste'"],
#    [u'politics', u"MPs to debate 'euthanasia laws'"],
#    [u'politics', u"Parties warned over 'grey vote'"],
#    [u'politics', u'BNP leader Nick Griffin arrested'],
#    [u'politics', u"Crisis 'ahead in social sciences'"],
#    [u'politics', u"Talks held on Gibraltar's future"],
#    [u'politics', u"Student 'fee factor' played down"],
#    [u'politics', u"Tory leader 'cleared' over work"],
#    [u'politics', u'Kelly trails new discipline power'],
#    [u'politics', u'Lords wrong on detainees - Straw'],
#    [u'politics', u'Scots smoking ban details set out'],
#    [u'politics', u"Royal couple watch nation's mood"],
#    [u'politics', u'Talks aim to avert pension strike'],
#    [u'politics', u'Crucial decision on super-casinos'],
#    [u'politics', u"Labour's 'EU propaganda'"],
#    [u'sport', u'Mido makes third apology'],
#    [u'sport', u'Smith keen on Home series return'],
#    [u'sport', u'Man City 0-2 Man Utd'],
#    [u'sport', u'Ronaldo considering new contract'],
#    [u'sport', u'Newcastle 2-1 Bolton'],
#    [u'sport', u'Man Utd stroll to Cup win'],
#    [u'sport', u'Moyes U-turn on Beattie dismissal'],
#    [u'sport', u'Chelsea clinch cup in extra-time'],
#    [u'entertainment', u"Redford's vision of Sundance"],
#    [u'entertainment', u'US TV cuts nudity from BBC film'],
#    [u'entertainment', u"UK's National Gallery in the pink"],
#    [u'entertainment', u"'Landmark movies' of 2004 hailed"],
#    [u'entertainment', u'DVD review: Spider-Man 2'],
#    [u'entertainment', u'Spike Lee backs student directors'],
#    [u'entertainment', u'Fears raised over ballet future'],
#    [u'entertainment', u'Mutant book wins Guardian prize'],
#    [u'entertainment', u"Willis sues over movie 'injury'"],
#    [u'entertainment', u'Uganda bans Vagina Monologues']]),
#  (5,
#   [[u'tech', u'Honour for UK games maker'],
#    [u'tech', u'BBC leads interactive Bafta wins'],
#    [u'tech', u'Creator of first Apple Mac dies'],
#    [u'politics', u'PM apology over jailings'],
#    [u'politics', u'Straw to attend Auschwitz service'],
#    [u'sport', u'Van Nistelrooy set to return'],
#    [u'entertainment', u'Musical treatment for Capra film'],
#    [u'entertainment', u'US critics laud comedy Sideways'],
#    [u'entertainment', u'Horror film heads US box office'],
#    [u'entertainment', u'Fockers fuel festive film chart'],
#    [u'entertainment', u"Brando 'rejected Godfather role'"],
#    [u'entertainment', u"Ocean's Twelve raids box office"],
#    [u'entertainment', u'Spark heads world Booker list'],
#    [u'entertainment', u'Slater to star in Broadway play'],
#    [u'entertainment', u'Animation charms Japan box office'],
#    [u'entertainment', u"Film row over Pirates 'cannibals'"],
#    [u'entertainment', u'Indie film nominations announced'],
#    [u'entertainment', u"Singer's film to show at festival"],
#    [u'entertainment', u'Adventure tale tops awards'],
#    [u'entertainment', u'Actor Foxx sees Globe nominations'],
#    [u'entertainment', u'Jarre joins fairytale celebration'],
#    [u'entertainment', u'Hollywood ready for Oscars night'],
#    [u'entertainment', u'Levy tipped for Whitbread prize'],
#    [u'entertainment', u"Cage film's third week at US top"],
#    [u'entertainment', u'Levy takes Whitbread novel prize'],
#    [u'entertainment', u"Aviator 'creator' in Oscars snub"],
#    [u'entertainment', u'No ads for Passion Oscar campaign'],
#    [u'entertainment', u'God cut from Dark Materials film'],
#    [u'entertainment', u'Hanks greeted at wintry premiere'],
#    [u'entertainment', u'Paraguay novel wins US book prize'],
#    [u'entertainment', u'Berlin hails European cinema'],
#    [u'entertainment', u'Sky takes over Oscar night mantle'],
#    [u'entertainment', u'Children vote Shrek 2 best film'],
#    [u'entertainment', u'Berlin honours S Korean director'],
#    [u'entertainment', u"Dutch watch Van Gogh's last film"],
#    [u'entertainment', u'Global release for Japan hit film'],
#    [u'entertainment', u'Public show for Reynolds portrait'],
#    [u'entertainment', u"Oscar nominee Dan O'Herlihy dies"],
#    [u'entertainment', u'Baby becomes new Oscar favourite'],
#    [u'entertainment', u"Howl helps boost Japan's cinemas"],
#    [u'entertainment', u'Lit Idol begins search for author'],
#    [u'entertainment', u"Da Vinci Code is 'lousy history'"],
#    [u'entertainment', u'Low-budget film wins Cesar'],
#    [u'entertainment', u'Church anger over Bollywood film'],
#    [u'entertainment', u'Baghdad Blogger on big screen'],
#    [u'entertainment', u'Tautou film tops Cesar prize nods'],
#    [u'entertainment', u'US box office set for record high'],
#    [u'entertainment', u'Poppins musical gets flying start'],
#    [u'entertainment', u"Director Nair's Vanity project"],
#    [u'entertainment', u'Oscars race enters final furlong'],
#    [u'entertainment', u'DVD review: Harry Potter and the Prisoner of Azkaban'],
#    [u'entertainment', u'UK debut for Kevin Spacey movie'],
#    [u'entertainment', u'Godzilla gets Hollywood fame star'],
#    [u'entertainment', u'Neeson in bid to revive theatre'],
#    [u'entertainment', u'Bennett play takes theatre prizes'],
#    [u'entertainment', u'Vera Drake scoops film award'],
#    [u'entertainment', u'Snicket tops US box office chart'],
#    [u'entertainment', u'US actor Ossie Davis found dead'],
#    [u'entertainment', u'Oscar nominees gear up for lunch'],
#    [u'entertainment', u'Potter director signs Warner deal'],
#    [u'entertainment', u'Berlin cheers for anti-Nazi film'],
#    [u'entertainment', u'Russian film wins BBC world prize'],
#    [u'entertainment', u'West End to honour finest shows'],
#    [u'entertainment', u'Richard and Judy choose top books'],
#    [u'entertainment', u"Wine comedy wins critics' award"],
#    [u'entertainment', u'Da Vinci film to star Tom Hanks'],
#    [u'entertainment', u'Ray DVD beats box office takings'],
#    [u'entertainment', u'Bookmakers back Aviator for Oscar'],
#    [u'entertainment', u'Foxx and Swank win US awards'],
#    [u'entertainment', u'Obituary: Dame Alicia Markova'],
#    [u'entertainment', u'Stars gear up for Bafta ceremony'],
#    [u'entertainment', u'Box office blow for Alexander'],
#    [u'entertainment', u"Dirty Den's demise seen by 14m"],
#    [u'entertainment', u'Aviator wins top Globes accolades'],
#    [u'entertainment', u'New Harry Potter tops book chart'],
#    [u'entertainment', u'Surprise win for anti-Bush film'],
#    [u'entertainment', u'Spirit awards hail Sideways'],
#    [u'entertainment', u'Hundreds vie for best film Oscar'],
#    [u'entertainment', u'De Niro film leads US box office'],
#    [u'entertainment', u'Famed music director Viotti dies'],
#    [u'entertainment', u"Tautou 'to star in Da Vinci film'"],
#    [u'entertainment', u'Stars pay tribute to actor Davis'],
#    [u'entertainment', u"Ocean's Twelve raids box office"],
#    [u'entertainment', u'Arthur Hailey: King of the bestsellers'],
#    [u'entertainment', u'Berlin applauds Hotel Rwanda'],
#    [u'entertainment', u"Jugnot 'tops French actor league'"],
#    [u'entertainment', u'DVD review: I, Robot'],
#    [u'entertainment', u'Wine comedy up for six film gongs'],
#    [u'entertainment', u'Foxx and Swank take actors awards'],
#    [u'entertainment', u"Aviator 'creator' in Oscars snub"]])]

# %%
#here we try to learn from each center of cluster which words are have strong connection to the cluster

# %%
def top20WordsFromVector(vector):
    words = []
    keys = broadcastDFt.value.keys()
    for i in range(0, vector_size):
        if vector[i] > 0.0:
            words.append((vector[i],keys[i]))
        if len(words)>20:
            minW = float("inf")
            minElement = None
            for element in words:
                if(element[0] < minW):
                    minW = element[0]
                    minElement = element
            words.remove(minElement)
    return map(lambda x: x[1],words)

# %%
def getTopWordsForEveryCluster(cluster):
    words_cluster={}
    keys = cluster.keys()
    for key in keys:
        words_cluster[key] = top20WordsFromVector(cluster[key])
    return words_cluster

# %%
words_cluster = getTopWordsForEveryCluster(centers)
words_cluster
# Out:
# {1: [u'internet',
#   u'information',
#   u'virus',
#   u'firm',
#   u'software',
#   u'web',
#   u'websites',
#   u'online',
#   u'spyware',
#   u'using',
#   u'computer',
#   u'net',
#   u'programs',
#   u'mail',
#   u'microsoft',
#   u'security',
#   u'program',
#   u'windows',
#   u'users',
#   u'use'],
#  2: [u'financial',
#   u'debt',
#   u'sale',
#   u'firm',
#   u'bn',
#   u'owned',
#   u'production',
#   u'shares',
#   u'market',
#   u'sales',
#   u'investment',
#   u'deal',
#   u'profits',
#   u'group',
#   u'oil',
#   u'chief',
#   u'executive',
#   u'company',
#   u'profit',
#   u'growth'],
#  3: [u'say',
#   u'many',
#   u'ministers',
#   u'government',
#   u'secretary',
#   u'labour',
#   u'blair',
#   u'economic',
#   u'need',
#   u'party',
#   u'mr',
#   u'public',
#   u'would',
#   u'report',
#   u'election',
#   u'says',
#   u'plans',
#   u'minister',
#   u'economy',
#   u'bbc'],
#  4: [u'birmingham',
#   u'training',
#   u'world',
#   u'iaaf',
#   u'gold',
#   u'race',
#   u'holmes',
#   u'thanou',
#   u'medal',
#   u'championships',
#   u'sport',
#   u'win',
#   u'indoor',
#   u'kenteris',
#   u'olympics',
#   u'olympic',
#   u'season',
#   u'athletics',
#   u'athens',
#   u'champion'],
#  5: [u'prize',
#   u'nominated',
#   u'best',
#   u'starring',
#   u'films',
#   u'director',
#   u'movie',
#   u'comedy',
#   u'award',
#   u'oscars',
#   u'actor',
#   u'star',
#   u'oscar',
#   u'hollywood',
#   u'aviator',
#   u'film',
#   u'awards',
#   u'ceremony',
#   u'actress',
#   u'academy']}

# %%
#Strong word for every cluster
# 1) (tech) => internet, virus, software, web, websites, online, spyware, computer, 
#              programs, mail, microsoft',u'security',u'program',u'windows',u'users',
#
# 2) (business) => financial, debt, sale, owned, production, market, sales,
#                  investment, deal, profits, company, profit, growth
#
# 3) (politics) => ministers, government, labour, party, election, minister
#
# 4) (sport) => training, world, race, medal, championships ,sport, win
#               olympics, olympic, season, athletics, athens, champion
#
# 5) (entertainment) =>  prize, starring, films, director, movie, comedy, award
#                        oscars, actor, star, oscar, hollywood, film, awards, ceremony
